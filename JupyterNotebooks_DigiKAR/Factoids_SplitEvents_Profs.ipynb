# %% [markdown]
# This is a script for splitting multiple events in the OCR + API Prof Data.

# %%
## mount drive
from google.colab import drive
drive.mount("/content/drive")
directory="/content/drive/My Drive/Colab_DigiKAR/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# In the second step, we have to install additional Packages needed for working with CSV, EXCEL and DataFrames.

# %%
## install packages that are not part of Python's standard distribution

# !pip install xlsxwriter
# !pip install pandas
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.9-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 KB 2.8 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (1.22.4)

# %% [markdown]
# In **step 1**, we can import the packages to the script and load our data. Before merging the input files, names will be normalised as some have access spaces, capitalised surnames, or inverted first and last names.
#
# The combined data will be written to a new dataframe and displayed.

# %%
import xlsxwriter
import csv
import pandas as pd
from pandas import DataFrame
import numpy as np
import os
import re

# path to input files

file_path="https://github.com/ieg-dhr/DigiKAR/blob/main/Sample%20Data/Factoid_PROFS_consolidation_STEP2_events-reconstructed.xlsx?raw=true"

# define dataframe for final output

f_to_add=[]

# structure of input files

# obligatory columns in valid factoid list

column_names = ["factoid_ID",
                "pers_ID",
                "alternative_names",
                "event_type",
                "event_after-date",
                "event_before-date",
                "event_start",
                "event_end",
                "event_date",
                "pers_title",
                "pers_function",
                "place_name",
                "inst_name",
                "rel_pers",
                "source_quotations",
                "additional_info",
                "comment",
                "info_dump",
                "source",
                "source_site"]
                


df = pd.read_excel(file_path, index_col=None, dtype=str) # axis=1, sort=False sheet_name='FactoidList'
df = df.fillna("n/a") # replace empty fields for string
df_length=len(df)

print("There are ", len(df), "items in your DataFrame!")

# delete all duplicate rows with exact matches

df_unique=df.drop_duplicates()
print("Your DataFrame has now ", len(df_unique), "items with at least one unique cell." )

display(df_unique)
# Out:
# There are  29449 items in your DataFrame!
# Your DataFrame has now  29449 items with at least one unique cell.
#       Unnamed: 0.1 factoid_ID pers_ID                             pers_name  \
# 0             1222        286     API              Wendelin Wendelin Dietes
# 1             1223        455     API  Matthäus Anton Chrysostomus Eberwein
# 2             1225        809     API                 Bertold Georg Gothelp
# 3             1228       2617     API            Alexander Günther Samhaber
# 4             1233       3462     API                Damian Friedrich Boost
# ...            ...        ...     ...                                   ...
# 29444        29319       7092     OCR             Johann Michael Wunderlich
# 29445        29332       4021     OCR            Johann Friedrich Wüstefled
# 29446        29346       7099     OCR                           Georg Zeder
# 29447        29356       5057     OCR                         Thomas Zenzen
# 29448        29447       7151     OCR             (Johannes) Jakob Zweiffel
#
#       alternative_names         event_type event_after-date event_before-date  \
# 0                   n/a  Funktionsausübung              n/a               n/a
# 1                   n/a        Amtsantritt              n/a               n/a
# 2                   n/a        Amtsantritt              n/a               n/a
# 3                   n/a        Amtsantritt              n/a               n/a
# 4                   n/a        Amtsantritt              n/a               n/a
# ...                 ...                ...              ...               ...
# 29444               n/a          Zulassung              n/a               n/a
# 29445        Wüstenfeld          Zulassung              n/a               n/a
# 29446               n/a          Zulassung       1765-06-26               n/a
# 29447               n/a          Zulassung       1788-07-29               n/a
# 29448           Zweifel          Zulassung              n/a               n/a
#
#             event_start         event_end  ...     place_name  \
# 0            1616-01-01        1646-12-31  ...  Aschaffenburg
# 1                   n/a               n/a  ...          Mainz
# 2                   n/a               n/a  ...          Mainz
# 3                   n/a               n/a  ...            n/a
# 4            1779-02-03        1779-02-03  ...            n/a
# ...                 ...               ...  ...            ...
# 29444  1737, 1737-11-26  1737, 1737-11-26  ...          Mainz
# 29445  1770, 1770-12-31  1770, 1770-12-31  ...          Mainz
# 29446               n/a               n/a  ...            n/a
# 29447               n/a               n/a  ...   Mainz, Trier
# 29448        1766-01-08        1766-01-08  ...            n/a
#
#                                                inst_name rel_pers  \
# 0      Kollegiatstift St. Peter und Alexander Aschaff...      n/a
# 1                                       St. Viktor Mainz      n/a
# 2                                        St. Peter Mainz      n/a
# 3                                        Augustinerorden      n/a
# 4                                        Concilium Majus      n/a
# ...                                                  ...      ...
# 29444         Universität Mainz, Philosophische Fakultät      n/a
# 29445                                                n/a      n/a
# 29446                                    Concilium Majus      n/a
# 29447                                  Universität Trier      n/a
# 29448                                    Concilium Majus      n/a
#
#       source_quotations                                    additional_info  \
# 0                   n/a  \nLektoratspräbende Stift St. Peter und Alexan...
# 1                   n/a     \nLektoratspräbende Stift St. Viktor (Mainz)\n
# 2                   n/a                                                n/a
# 3                   n/a                                \nAugustinerorden\n
# 4                   n/a                                \nConcilium majus\n
# ...                 ...                                                ...
# 29444               n/a  1737 wurde er in Mainz zur Artistenfakultät zu...
# 29445               n/a  er bewarb sich in Mainz 1770 als ao. Professor...
# 29446               n/a  am 26.6.1765 wurde er zum Concilium majus zuge...
# 29447               n/a  Trier am 29.7.1788 bat er in Mainz um Zulassun...
# 29448               n/a  am 8.1.1766 wurde er zum Concilium majus zugel...
#
#       comment info_dump                                             source  \
# 0         n/a       n/a                                            ProfAPI
# 1         n/a       n/a                                            ProfAPI
# 2         n/a       n/a                                            ProfAPI
# 3         n/a       n/a                                            ProfAPI
# 4         n/a       n/a                                            ProfAPI
# ...       ...       ...                                                ...
# 29444     n/a       n/a   Praetorius, Professoren, S.137; \n RPh 63v, 6...
# 29445     n/a       n/a   Praetorius, Professoren, S.100; \n RR II 91; ...
# 29446     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
# 29447     n/a       n/a   Praetorius, Professoren, S.134; \n Prot. med....
# 29448     n/a       n/a   Praetorius, Professoren, S.138; \n RR I 81v; ...
#
#                                              source_site Unnamed: 0
# 0      http://gutenberg-biographics.ub.uni-mainz.de/i...          0
# 1      http://gutenberg-biographics.ub.uni-mainz.de/i...          1
# 2      http://gutenberg-biographics.ub.uni-mainz.de/i...          3
# 3      http://gutenberg-biographics.ub.uni-mainz.de/i...          6
# 4      http://gutenberg-biographics.ub.uni-mainz.de/i...         11
# ...                                                  ...        ...
# 29444                                                n/a       8887
# 29445                                                n/a       8900
# 29446                                                n/a       8914
# 29447                                                n/a       8924
# 29448                                                n/a       9015
#
# [29449 rows x 23 columns]

# %% [markdown]
# In **step 2**, we identify cells with comma-separated values and split them.

# %%
df2 = df_unique
df_size=len(df2)

# find cells with commas in the pers_function column
list_to_append=[]
try:
  for x in range(0, df_size):
      print(df_size - x)
      e_df=df2.iloc[[x]].fillna("n/a") # virtual value to avoid issues with empty data frames
  
      if "," in e_df['pers_function'].values[0]:
        e_functions=e_df['pers_function'].values[0]
        function_list=e_functions.split(",")
        for function in function_list:
          print(function)
          e_df["pers_function"]=function
          print(e_df)
          list_to_append.append(e_df)

      else:
        print("Only one value found.")

except Exception as e:
  print(e)

df_split = pd.concat(list_to_append, axis=0, ignore_index=True, sort=False)
display(df_split)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1160
# Only one value found.
# 1159
# Only one value found.
# 1158
# Only one value found.
# 1157
# Only one value found.
# 1156
# Only one value found.
# 1155
# Only one value found.
# 1154
# Only one value found.
# 1153
# Only one value found.
# 1152
# Only one value found.
# 1151
# Only one value found.
# 1150
# Only one value found.
# 1149
# Only one value found.
# 1148
# Only one value found.
# 1147
# Only one value found.
# 1146
# Only one value found.
# 1145
# Only one value found.
# 1144
# Only one value found.
# 1143
# Only one value found.
# 1142
# Mitglied
#       Unnamed: 0.1 factoid_ID pers_ID             pers_name alternative_names  \
# 28307        23126       4147     OCR  Johann Anton Caprano               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 28307        Tod              n/a               n/a  1818-10-18  1818-10-18
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28307  ...      Mainz       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28307  + 18.10.1818 als Mitglied der Medizinischen Ze...     n/a       n/a
#
#                                                   source source_site  \
# 28307   Prot, phil. Fak., S.123, 145, 164; \n StAD VI...         n/a
#
#       Unnamed: 0
# 28307       2694
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID             pers_name alternative_names  \
# 28307        23126       4147     OCR  Johann Anton Caprano               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 28307        Tod              n/a               n/a  1818-10-18  1818-10-18
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28307  ...      Mainz       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28307  + 18.10.1818 als Mitglied der Medizinischen Ze...     n/a       n/a
#
#                                                   source source_site  \
# 28307   Prot, phil. Fak., S.123, 145, 164; \n StAD VI...         n/a
#
#       Unnamed: 0
# 28307       2694
#
# [1 rows x 23 columns]
# 1141
# Only one value found.
# 1140
# Only one value found.
# 1139
# Only one value found.
# 1138
# Only one value found.
# 1137
# Only one value found.
# 1136
# Only one value found.
# 1135
# Only one value found.
# 1134
# Only one value found.
# 1133
# Only one value found.
# 1132
# Only one value found.
# 1131
# Only one value found.
# 1130
# Only one value found.
# 1129
# Only one value found.
# 1128
# Only one value found.
# 1127
# Only one value found.
# 1126
# Only one value found.
# 1125
# Only one value found.
# 1124
# Only one value found.
# 1123
# Only one value found.
# 1122
# Only one value found.
# 1121
# Vogt
#       Unnamed: 0.1 factoid_ID pers_ID                pers_name  \
# 28328        23347       5563     OCR  Franz Christoph Dichtel
#
#       alternative_names event_type event_after-date event_before-date  \
# 28328           Düchtel        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name          inst_name rel_pers  \
# 28328  1789-11-25  1789-11-25  ...      Mainz  Universität Mainz      n/a
#
#       source_quotations                                    additional_info  \
# 28328               n/a  nach dem Tod von Joh. Heinrich Vogt (25.11.178...
#
#       comment info_dump                                             source  \
# 28328     n/a       n/a   RR II 189, 199, 234; \n Heß, Nr. 9614; \n Pal...
#
#       source_site Unnamed: 0
# 28328         n/a       2915
#
# [1 rows x 23 columns]
#  Bibliothekar
#       Unnamed: 0.1 factoid_ID pers_ID                pers_name  \
# 28328        23347       5563     OCR  Franz Christoph Dichtel
#
#       alternative_names event_type event_after-date event_before-date  \
# 28328           Düchtel        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name          inst_name rel_pers  \
# 28328  1789-11-25  1789-11-25  ...      Mainz  Universität Mainz      n/a
#
#       source_quotations                                    additional_info  \
# 28328               n/a  nach dem Tod von Joh. Heinrich Vogt (25.11.178...
#
#       comment info_dump                                             source  \
# 28328     n/a       n/a   RR II 189, 199, 234; \n Heß, Nr. 9614; \n Pal...
#
#       source_site Unnamed: 0
# 28328         n/a       2915
#
# [1 rows x 23 columns]
# 1120
# Only one value found.
# 1119
# Only one value found.
# 1118
# Only one value found.
# 1117
# Only one value found.
# 1116
# Only one value found.
# 1115
# Only one value found.
# 1114
# Only one value found.
# 1113
# Only one value found.
# 1112
# Only one value found.
# 1111
# Only one value found.
# 1110
# Only one value found.
# 1109
# Only one value found.
# 1108
# Only one value found.
# 1107
# Only one value found.
# 1106
# Only one value found.
# 1105
# Only one value found.
# 1104
# Only one value found.
# 1103
# Only one value found.
# 1102
# Only one value found.
# 1101
# Only one value found.
# 1100
# Only one value found.
# 1099
# Only one value found.
# 1098
# Only one value found.
# 1097
# Only one value found.
# 1096
# Only one value found.
# 1095
# Only one value found.
# 1094
# Only one value found.
# 1093
# Only one value found.
# 1092
# Only one value found.
# 1091
# Only one value found.
# 1090
# Only one value found.
# 1089
# Only one value found.
# 1088
# Only one value found.
# 1087
# Only one value found.
# 1086
# Only one value found.
# 1085
# Only one value found.
# 1084
# Kämmerer
#       Unnamed: 0.1 factoid_ID pers_ID    pers_name alternative_names  \
# 28365        23743       3007     OCR  Kilian Eler               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28365        Tod       1579-05-17               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28365  ...      Mainz       n/a      n/a               n/a
#
#                                 additional_info comment info_dump  \
# 28365  + 17.5.1579 als Kämmerer der Stadt Mainz     n/a       n/a
#
#                                                   source source_site  \
# 28365   Praetorius, Professoren, S.97; \n Borg. B. 31...         n/a
#
#       Unnamed: 0
# 28365       3311
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID    pers_name alternative_names  \
# 28365        23743       3007     OCR  Kilian Eler               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28365        Tod       1579-05-17               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28365  ...      Mainz       n/a      n/a               n/a
#
#                                 additional_info comment info_dump  \
# 28365  + 17.5.1579 als Kämmerer der Stadt Mainz     n/a       n/a
#
#                                                   source source_site  \
# 28365   Praetorius, Professoren, S.97; \n Borg. B. 31...         n/a
#
#       Unnamed: 0
# 28365       3311
#
# [1 rows x 23 columns]
# 1083
# Only one value found.
# 1082
# Only one value found.
# 1081
# Only one value found.
# 1080
# Only one value found.
# 1079
# Only one value found.
# 1078
# Only one value found.
# 1077
# Only one value found.
# 1076
# Only one value found.
# 1075
# Only one value found.
# 1074
# Only one value found.
# 1073
# Only one value found.
# 1072
# Only one value found.
# 1071
# Only one value found.
# 1070
# Only one value found.
# 1069
# Only one value found.
# 1068
# Only one value found.
# 1067
# Only one value found.
# 1066
# Only one value found.
# 1065
# Only one value found.
# 1064
# Only one value found.
# 1063
# Only one value found.
# 1062
# Only one value found.
# 1061
# Only one value found.
# 1060
# Only one value found.
# 1059
# Only one value found.
# 1058
# Only one value found.
# 1057
# Only one value found.
# 1056
# Only one value found.
# 1055
# Only one value found.
# 1054
# Only one value found.
# 1053
# Only one value found.
# 1052
# Only one value found.
# 1051
# Only one value found.
# 1050
# Only one value found.
# 1049
# Only one value found.
# 1048
# Only one value found.
# 1047
# Only one value found.
# 1046
# Only one value found.
# 1045
# Only one value found.
# 1044
# Only one value found.
# 1043
# Only one value found.
# 1042
# Only one value found.
# 1041
# Rektor
#       Unnamed: 0.1 factoid_ID pers_ID          pers_name alternative_names  \
# 28408        24204        884     OCR  Johann Georg Gaar               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 28408        Tod              n/a               n/a  1764-03-24  1764-03-24
#
#        ...     place_name             inst_name rel_pers source_quotations  \
# 28408  ...  Aschaffenburg  Kolleg Aschaffenburg      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28408  als Rektor des Kollegs in Aschaffenburg + 24.3...     n/a       n/a
#
#                                                   source source_site  \
# 28408   Praetorius, Professoren, S.95; \n RPh 108r, H...         n/a
#
#       Unnamed: 0
# 28408       3772
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID          pers_name alternative_names  \
# 28408        24204        884     OCR  Johann Georg Gaar               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 28408        Tod              n/a               n/a  1764-03-24  1764-03-24
#
#        ...     place_name             inst_name rel_pers source_quotations  \
# 28408  ...  Aschaffenburg  Kolleg Aschaffenburg      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28408  als Rektor des Kollegs in Aschaffenburg + 24.3...     n/a       n/a
#
#                                                   source source_site  \
# 28408   Praetorius, Professoren, S.95; \n RPh 108r, H...         n/a
#
#       Unnamed: 0
# 28408       3772
#
# [1 rows x 23 columns]
# 1040
# Only one value found.
# 1039
# Only one value found.
# 1038
# Only one value found.
# 1037
# Only one value found.
# 1036
# Only one value found.
# 1035
# Only one value found.
# 1034
# Only one value found.
# 1033
# Only one value found.
# 1032
# Only one value found.
# 1031
# Only one value found.
# 1030
# Pfarrer
#       Unnamed: 0.1 factoid_ID pers_ID             pers_name alternative_names  \
# 28419        24328        929     OCR  Lorenz Germershausen               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28419        Tod       1783-01-22               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28419  ...   Oestrich       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28419  + 22.1.1783 als Pfarrer in Oestrich, 71 Jahre alt     n/a       n/a
#
#                                                   source source_site  \
# 28419   Praetorius, Professoren, S.95; \n RR I 73v; \...         n/a
#
#       Unnamed: 0
# 28419       3896
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID             pers_name alternative_names  \
# 28419        24328        929     OCR  Lorenz Germershausen               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28419        Tod       1783-01-22               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28419  ...   Oestrich       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28419  + 22.1.1783 als Pfarrer in Oestrich, 71 Jahre alt     n/a       n/a
#
#                                                   source source_site  \
# 28419   Praetorius, Professoren, S.95; \n RR I 73v; \...         n/a
#
#       Unnamed: 0
# 28419       3896
#
# [1 rows x 23 columns]
# 1029
# Only one value found.
# 1028
# Only one value found.
# 1027
# Only one value found.
# 1026
# Only one value found.
# 1025
# Only one value found.
# 1024
# Only one value found.
# 1023
# Only one value found.
# 1022
# Only one value found.
# 1021
# Only one value found.
# 1020
# Only one value found.
# 1019
# Only one value found.
# 1018
# Only one value found.
# 1017
# Only one value found.
# 1016
# Only one value found.
# 1015
# Only one value found.
# 1014
# Rat
#       Unnamed: 0.1 factoid_ID pers_ID         pers_name alternative_names  \
# 28435        24573       3247     OCR  Edmund von Hagen               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28435        Tod       1794-01-27               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28435  ...      Worms       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28435  (ein Ed. von Hagen, Wormser Rat + Q 27.1.1794 ...     n/a       n/a
#
#                                                   source source_site  \
# 28435   RPh 313v, 316r; \n RR II 357; \n Prot. phil. ...         n/a
#
#       Unnamed: 0
# 28435       4141
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID         pers_name alternative_names  \
# 28435        24573       3247     OCR  Edmund von Hagen               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28435        Tod       1794-01-27               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28435  ...      Worms       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28435  (ein Ed. von Hagen, Wormser Rat + Q 27.1.1794 ...     n/a       n/a
#
#                                                   source source_site  \
# 28435   RPh 313v, 316r; \n RR II 357; \n Prot. phil. ...         n/a
#
#       Unnamed: 0
# 28435       4141
#
# [1 rows x 23 columns]
# 1013
# Only one value found.
# 1012
# Only one value found.
# 1011
# Only one value found.
# 1010
# Only one value found.
# 1009
# Only one value found.
# 1008
# Only one value found.
# 1007
# Only one value found.
# 1006
# Only one value found.
# 1005
# Only one value found.
# 1004
# Only one value found.
# 1003
# Only one value found.
# 1002
# Only one value found.
# 1001
# Only one value found.
# 1000
# Only one value found.
# 999
# Only one value found.
# 998
# Only one value found.
# 997
# Only one value found.
# 996
# Only one value found.
# 995
# Only one value found.
# 994
# Only one value found.
# 993
# Only one value found.
# 992
# Only one value found.
# 991
# Only one value found.
# 990
# Only one value found.
# 989
# Only one value found.
# 988
# Only one value found.
# 987
# Only one value found.
# 986
# Only one value found.
# 985
# Only one value found.
# 984
# Only one value found.
# 983
# Only one value found.
# 982
# Only one value found.
# 981
# Only one value found.
# 980
# Only one value found.
# 979
# Only one value found.
# 978
# Only one value found.
# 977
# Only one value found.
# 976
# Only one value found.
# 975
# Only one value found.
# 974
# Only one value found.
# 973
# Assessor
#       Unnamed: 0.1 factoid_ID pers_ID                   pers_name  \
# 28476        25121       3346     OCR  Johannes Ambrosius Höglein
#
#       alternative_names event_type event_after-date event_before-date  \
# 28476               n/a        Tod       1701-09-21               n/a
#
#       event_start event_end  ... place_name inst_name rel_pers  \
# 28476        1690      1690  ...        n/a       n/a      n/a
#
#       source_quotations                               additional_info comment  \
# 28476               n/a  1690 als Assessor jur. genannt + E 21.9.1701     n/a
#
#       info_dump                                             source  \
# 28476       n/a   Praetorius, Professoren, S.98; \n Prot. jur. ...
#
#       source_site Unnamed: 0
# 28476         n/a       4689
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID                   pers_name  \
# 28476        25121       3346     OCR  Johannes Ambrosius Höglein
#
#       alternative_names event_type event_after-date event_before-date  \
# 28476               n/a        Tod       1701-09-21               n/a
#
#       event_start event_end  ... place_name inst_name rel_pers  \
# 28476        1690      1690  ...        n/a       n/a      n/a
#
#       source_quotations                               additional_info comment  \
# 28476               n/a  1690 als Assessor jur. genannt + E 21.9.1701     n/a
#
#       info_dump                                             source  \
# 28476       n/a   Praetorius, Professoren, S.98; \n Prot. jur. ...
#
#       source_site Unnamed: 0
# 28476         n/a       4689
#
# [1 rows x 23 columns]
# 972
# Only one value found.
# 971
# Only one value found.
# 970
# Only one value found.
# 969
# Only one value found.
# 968
# Only one value found.
# 967
# Only one value found.
# 966
# Assessor
#       Unnamed: 0.1 factoid_ID pers_ID             pers_name  \
# 28483        25183       3364     OCR  Heinrich Holtzgreven
#
#            alternative_names event_type event_after-date event_before-date  \
# 28483  Holzgreven, Holtzgraf        Tod              n/a               n/a
#
#       event_start event_end  ... place_name   inst_name rel_pers  \
# 28483        1679      1679  ...        n/a  Hofgericht      n/a
#
#       source_quotations                                    additional_info  \
# 28483               n/a  + 1679, an seine Stelle kommt Hofgerichtsasses...
#
#       comment info_dump                                             source  \
# 28483     n/a       n/a   Praetorius, Professoren, S.98; \n StAD VI,1/ ...
#
#       source_site Unnamed: 0
# 28483         n/a       4751
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID             pers_name  \
# 28483        25183       3364     OCR  Heinrich Holtzgreven
#
#            alternative_names event_type event_after-date event_before-date  \
# 28483  Holzgreven, Holtzgraf        Tod              n/a               n/a
#
#       event_start event_end  ... place_name   inst_name rel_pers  \
# 28483        1679      1679  ...        n/a  Hofgericht      n/a
#
#       source_quotations                                    additional_info  \
# 28483               n/a  + 1679, an seine Stelle kommt Hofgerichtsasses...
#
#       comment info_dump                                             source  \
# 28483     n/a       n/a   Praetorius, Professoren, S.98; \n StAD VI,1/ ...
#
#       source_site Unnamed: 0
# 28483         n/a       4751
#
# [1 rows x 23 columns]
# 965
# Only one value found.
# 964
# Only one value found.
# 963
# Only one value found.
# 962
# Only one value found.
# 961
# Only one value found.
# 960
# Only one value found.
# 959
# Only one value found.
# 958
# Only one value found.
# 957
# Only one value found.
# 956
# Only one value found.
# 955
# Only one value found.
# 954
# Only one value found.
# 953
# Only one value found.
# 952
# Only one value found.
# 951
# Only one value found.
# 950
# Only one value found.
# 949
# Only one value found.
# 948
# Only one value found.
# 947
# Only one value found.
# 946
# Only one value found.
# 945
# Only one value found.
# 944
# Only one value found.
# 943
# Only one value found.
# 942
# Only one value found.
# 941
# Only one value found.
# 940
# Only one value found.
# 939
# Only one value found.
# 938
# Only one value found.
# 937
# Only one value found.
# 936
# Only one value found.
# 935
# Only one value found.
# 934
# Ältester
#       Unnamed: 0.1 factoid_ID pers_ID                  pers_name  \
# 28515        25546        368     OCR  Heinrich Matthias Kaupers
#
#       alternative_names event_type event_after-date event_before-date  \
# 28515               n/a        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name inst_name rel_pers  \
# 28515  1744-06-06  1744-06-06  ...        n/a       n/a      n/a
#
#       source_quotations                               additional_info comment  \
# 28515               n/a  Senior aus dem Haus Schenkenberg, + 6.6.1744     n/a
#
#       info_dump                                             source  \
# 28515       n/a   Praetorius, Professoren, S.95; \n RPh 13r, 14...
#
#       source_site Unnamed: 0
# 28515         n/a       5114
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID                  pers_name  \
# 28515        25546        368     OCR  Heinrich Matthias Kaupers
#
#       alternative_names event_type event_after-date event_before-date  \
# 28515               n/a        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name inst_name rel_pers  \
# 28515  1744-06-06  1744-06-06  ...        n/a       n/a      n/a
#
#       source_quotations                               additional_info comment  \
# 28515               n/a  Senior aus dem Haus Schenkenberg, + 6.6.1744     n/a
#
#       info_dump                                             source  \
# 28515       n/a   Praetorius, Professoren, S.95; \n RPh 13r, 14...
#
#       source_site Unnamed: 0
# 28515         n/a       5114
#
# [1 rows x 23 columns]
# 933
# Only one value found.
# 932
# Only one value found.
# 931
# Only one value found.
# 930
# Only one value found.
# 929
# Only one value found.
# 928
# Only one value found.
# 927
# Only one value found.
# 926
# Only one value found.
# 925
# Only one value found.
# 924
# Only one value found.
# 923
# Only one value found.
# 922
# Only one value found.
# 921
# Only one value found.
# 920
# Only one value found.
# 919
# Only one value found.
# 918
# Only one value found.
# 917
# Only one value found.
# 916
# Only one value found.
# 915
# Only one value found.
# 914
# Only one value found.
# 913
# Only one value found.
# 912
# Only one value found.
# 911
# Only one value found.
# 910
# Only one value found.
# 909
# Only one value found.
# 908
# Only one value found.
# 907
# Only one value found.
# 906
# Only one value found.
# 905
# Only one value found.
# 904
# Only one value found.
# 903
# Only one value found.
# 902
# Only one value found.
# 901
# Only one value found.
# 900
# Only one value found.
# 899
# Only one value found.
# 898
# Only one value found.
# 897
# Only one value found.
# 896
# Only one value found.
# 895
# Only one value found.
# 894
# Only one value found.
# 893
# Only one value found.
# 892
# Only one value found.
# 891
# Only one value found.
# 890
# Only one value found.
# 889
# Only one value found.
# 888
# Only one value found.
# 887
# Only one value found.
# 886
# Only one value found.
# 885
# Only one value found.
# 884
# Only one value found.
# 883
# Only one value found.
# 882
# Only one value found.
# 881
# Only one value found.
# 880
# Only one value found.
# 879
# Only one value found.
# 878
# Only one value found.
# 877
# Only one value found.
# 876
# Only one value found.
# 875
# Only one value found.
# 874
# Only one value found.
# 873
# Only one value found.
# 872
# Only one value found.
# 871
# Only one value found.
# 870
# Only one value found.
# 869
# Only one value found.
# 868
# Only one value found.
# 867
# Only one value found.
# 866
# Only one value found.
# 865
# Only one value found.
# 864
# Only one value found.
# 863
# Only one value found.
# 862
# Only one value found.
# 861
# Only one value found.
# 860
# Only one value found.
# 859
# Only one value found.
# 858
# Only one value found.
# 857
# Only one value found.
# 856
# Only one value found.
# 855
# Only one value found.
# 854
# Only one value found.
# 853
# Only one value found.
# 852
# Only one value found.
# 851
# Only one value found.
# 850
# Only one value found.
# 849
# Only one value found.
# 848
# Only one value found.
# 847
# Only one value found.
# 846
# Only one value found.
# 845
# Only one value found.
# 844
# Only one value found.
# 843
# Only one value found.
# 842
# Only one value found.
# 841
# Only one value found.
# 840
# Only one value found.
# 839
# Only one value found.
# 838
# Rektor
#       Unnamed: 0.1 factoid_ID pers_ID       pers_name alternative_names  \
# 28611        26614       1625     OCR  Kaspar Molitor               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28611        Tod       1750-04-17               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28611  ...     Speyer       n/a      n/a               n/a
#
#                         additional_info comment info_dump  \
# 28611  + 17.4.1750 als Rektor zu Speyer     n/a       n/a
#
#                                                   source source_site  \
# 28611   Praetorius, Professoren, S.95; \n Cat. Jes. o...         n/a
#
#       Unnamed: 0
# 28611       6182
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID       pers_name alternative_names  \
# 28611        26614       1625     OCR  Kaspar Molitor               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28611        Tod       1750-04-17               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28611  ...     Speyer       n/a      n/a               n/a
#
#                         additional_info comment info_dump  \
# 28611  + 17.4.1750 als Rektor zu Speyer     n/a       n/a
#
#                                                   source source_site  \
# 28611   Praetorius, Professoren, S.95; \n Cat. Jes. o...         n/a
#
#       Unnamed: 0
# 28611       6182
#
# [1 rows x 23 columns]
# 837
# Only one value found.
# 836
# Only one value found.
# 835
# Only one value found.
# 834
# Only one value found.
# 833
# Only one value found.
# 832
# Only one value found.
# 831
# Only one value found.
# 830
# Only one value found.
# 829
# Only one value found.
# 828
# Only one value found.
# 827
# Only one value found.
# 826
# Only one value found.
# 825
# Only one value found.
# 824
# Only one value found.
# 823
# Only one value found.
# 822
# Only one value found.
# 821
# Only one value found.
# 820
# Only one value found.
# 819
# Only one value found.
# 818
# Only one value found.
# 817
# Only one value found.
# 816
# Only one value found.
# 815
# Only one value found.
# 814
# Only one value found.
# 813
# Only one value found.
# 812
# Only one value found.
# 811
# Only one value found.
# 810
# Only one value found.
# 809
# Only one value found.
# 808
# Only one value found.
# 807
# Only one value found.
# 806
# Only one value found.
# 805
# Only one value found.
# 804
# Only one value found.
# 803
# Only one value found.
# 802
# Only one value found.
# 801
# Only one value found.
# 800
# Only one value found.
# 799
# Only one value found.
# 798
# Only one value found.
# 797
# Only one value found.
# 796
# Only one value found.
# 795
# Only one value found.
# 794
# Only one value found.
# 793
# Only one value found.
# 792
# Only one value found.
# 791
# Only one value found.
# 790
# Only one value found.
# 789
# Only one value found.
# 788
# Only one value found.
# 787
# Only one value found.
# 786
# Only one value found.
# 785
# Only one value found.
# 784
# Only one value found.
# 783
# Professor
#       Unnamed: 0.1 factoid_ID pers_ID                     pers_name  \
# 28666        27338       3671     OCR  Johann Georg Wilhelm Reineck
#
#       alternative_names event_type event_after-date event_before-date  \
# 28666            Reinek        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name inst_name rel_pers  \
# 28666  1778-02-07  1778-02-07  ...        n/a       n/a      n/a
#
#       source_quotations                 additional_info comment info_dump  \
# 28666               n/a  + P 7.2.1778 als ao. Professor     n/a       n/a
#
#                                                   source source_site  \
# 28666   RR II 123, 190; \n RPh 241v; \n Prot. jur. Fa...         n/a
#
#       Unnamed: 0
# 28666       6906
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID                     pers_name  \
# 28666        27338       3671     OCR  Johann Georg Wilhelm Reineck
#
#       alternative_names event_type event_after-date event_before-date  \
# 28666            Reinek        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name inst_name rel_pers  \
# 28666  1778-02-07  1778-02-07  ...        n/a       n/a      n/a
#
#       source_quotations                 additional_info comment info_dump  \
# 28666               n/a  + P 7.2.1778 als ao. Professor     n/a       n/a
#
#                                                   source source_site  \
# 28666   RR II 123, 190; \n RPh 241v; \n Prot. jur. Fa...         n/a
#
#       Unnamed: 0
# 28666       6906
#
# [1 rows x 23 columns]
# 782
# Only one value found.
# 781
# Only one value found.
# 780
# Only one value found.
# 779
# Only one value found.
# 778
# Only one value found.
# 777
# Only one value found.
# 776
# Only one value found.
# 775
# Only one value found.
# 774
# Only one value found.
# 773
# Only one value found.
# 772
# Only one value found.
# 771
# Only one value found.
# 770
# Only one value found.
# 769
# Only one value found.
# 768
# Only one value found.
# 767
# Only one value found.
# 766
# Only one value found.
# 765
# Only one value found.
# 764
# Only one value found.
# 763
# Rat
#       Unnamed: 0.1 factoid_ID pers_ID                 pers_name  \
# 28686        27578       3738     OCR  Friedrich Wilhelm Rüding
#
#       alternative_names event_type event_after-date event_before-date  \
# 28686               n/a        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name   inst_name rel_pers  \
# 28686  1781-04-05  1781-04-05  ...    Wetzlar  Hofgericht      n/a
#
#       source_quotations                        additional_info comment  \
# 28686               n/a  Hofgerichtsrat, + 5.4.1781 in Wetzlar     n/a
#
#       info_dump                                             source  \
# 28686       n/a   Praetorius, Professoren, S.99; \n RPh 104v, 1...
#
#       source_site Unnamed: 0
# 28686         n/a       7146
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID                 pers_name  \
# 28686        27578       3738     OCR  Friedrich Wilhelm Rüding
#
#       alternative_names event_type event_after-date event_before-date  \
# 28686               n/a        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name   inst_name rel_pers  \
# 28686  1781-04-05  1781-04-05  ...    Wetzlar  Hofgericht      n/a
#
#       source_quotations                        additional_info comment  \
# 28686               n/a  Hofgerichtsrat, + 5.4.1781 in Wetzlar     n/a
#
#       info_dump                                             source  \
# 28686       n/a   Praetorius, Professoren, S.99; \n RPh 104v, 1...
#
#       source_site Unnamed: 0
# 28686         n/a       7146
#
# [1 rows x 23 columns]
# 762
# Arzt
#       Unnamed: 0.1 factoid_ID pers_ID       pers_name alternative_names  \
# 28687        27586       4795     OCR  Wendelinus Ruf               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28687        Tod       1808-03-20               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28687  ...        n/a       n/a      n/a               n/a
#
#                                     additional_info comment info_dump  \
# 28687  + 20.3.1808 als Dr. med. und ausübender Arzt     n/a       n/a
#
#                                                   source source_site  \
# 28687   Prot, phil. Fak., S.222, 235, 240; \n Matr. G...         n/a
#
#       Unnamed: 0
# 28687       7154
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID       pers_name alternative_names  \
# 28687        27586       4795     OCR  Wendelinus Ruf               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28687        Tod       1808-03-20               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28687  ...        n/a       n/a      n/a               n/a
#
#                                     additional_info comment info_dump  \
# 28687  + 20.3.1808 als Dr. med. und ausübender Arzt     n/a       n/a
#
#                                                   source source_site  \
# 28687   Prot, phil. Fak., S.222, 235, 240; \n Matr. G...         n/a
#
#       Unnamed: 0
# 28687       7154
#
# [1 rows x 23 columns]
# 761
# Only one value found.
# 760
# Only one value found.
# 759
# Only one value found.
# 758
# Only one value found.
# 757
# Only one value found.
# 756
# Only one value found.
# 755
# Only one value found.
# 754
# Only one value found.
# 753
# Only one value found.
# 752
# Only one value found.
# 751
# Only one value found.
# 750
# Only one value found.
# 749
# Only one value found.
# 748
# Only one value found.
# 747
# Only one value found.
# 746
# Only one value found.
# 745
# Only one value found.
# 744
# Only one value found.
# 743
# Only one value found.
# 742
# Only one value found.
# 741
# Only one value found.
# 740
# Only one value found.
# 739
# Only one value found.
# 738
# Only one value found.
# 737
# Only one value found.
# 736
# Only one value found.
# 735
# Only one value found.
# 734
# Only one value found.
# 733
# Only one value found.
# 732
# Only one value found.
# 731
# Only one value found.
# 730
# Only one value found.
# 729
# Only one value found.
# 728
# Only one value found.
# 727
# Only one value found.
# 726
# Only one value found.
# 725
# Only one value found.
# 724
# Only one value found.
# 723
# Only one value found.
# 722
# Only one value found.
# 721
# Only one value found.
# 720
# Only one value found.
# 719
# Only one value found.
# 718
# Only one value found.
# 717
# Only one value found.
# 716
# Only one value found.
# 715
# Only one value found.
# 714
# Only one value found.
# 713
# Only one value found.
# 712
# Only one value found.
# 711
# Only one value found.
# 710
# Only one value found.
# 709
# Only one value found.
# 708
# Only one value found.
# 707
# Only one value found.
# 706
# Only one value found.
# 705
# Only one value found.
# 704
# Only one value found.
# 703
# Only one value found.
# 702
# Only one value found.
# 701
# Only one value found.
# 700
# Only one value found.
# 699
# Only one value found.
# 698
# Only one value found.
# 697
# Only one value found.
# 696
# Only one value found.
# 695
# Only one value found.
# 694
# Only one value found.
# 693
# Only one value found.
# 692
# Only one value found.
# 691
# Only one value found.
# 690
# Only one value found.
# 689
# Only one value found.
# 688
# Only one value found.
# 687
# Only one value found.
# 686
# Only one value found.
# 685
# Only one value found.
# 684
# Only one value found.
# 683
# Only one value found.
# 682
# Only one value found.
# 681
# Only one value found.
# 680
# Professor
#       Unnamed: 0.1 factoid_ID pers_ID           pers_name alternative_names  \
# 28769        28633       4340     OCR  Johannes Vogelmann               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28769        Tod             1739              1742         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28769  ...        n/a       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28769  er hatte während der letzten Jahre vor dem Tod...     n/a       n/a
#
#                                                   source source_site  \
# 28769   Praetorius, Professoren, S.133; \n Prot med. ...         n/a
#
#       Unnamed: 0
# 28769       8201
#
# [1 rows x 23 columns]
#  ordentlicher
#       Unnamed: 0.1 factoid_ID pers_ID           pers_name alternative_names  \
# 28769        28633       4340     OCR  Johannes Vogelmann               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28769        Tod             1739              1742         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28769  ...        n/a       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28769  er hatte während der letzten Jahre vor dem Tod...     n/a       n/a
#
#                                                   source source_site  \
# 28769   Praetorius, Professoren, S.133; \n Prot med. ...         n/a
#
#       Unnamed: 0
# 28769       8201
#
# [1 rows x 23 columns]
#  Professor
#       Unnamed: 0.1 factoid_ID pers_ID           pers_name alternative_names  \
# 28769        28633       4340     OCR  Johannes Vogelmann               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28769        Tod             1739              1742         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28769  ...        n/a       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28769  er hatte während der letzten Jahre vor dem Tod...     n/a       n/a
#
#                                                   source source_site  \
# 28769   Praetorius, Professoren, S.133; \n Prot med. ...         n/a
#
#       Unnamed: 0
# 28769       8201
#
# [1 rows x 23 columns]
#  Dekan
#       Unnamed: 0.1 factoid_ID pers_ID           pers_name alternative_names  \
# 28769        28633       4340     OCR  Johannes Vogelmann               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28769        Tod             1739              1742         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28769  ...        n/a       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28769  er hatte während der letzten Jahre vor dem Tod...     n/a       n/a
#
#                                                   source source_site  \
# 28769   Praetorius, Professoren, S.133; \n Prot med. ...         n/a
#
#       Unnamed: 0
# 28769       8201
#
# [1 rows x 23 columns]
# 679
# Only one value found.
# 678
# Rektor
#       Unnamed: 0.1 factoid_ID pers_ID   pers_name alternative_names  \
# 28771        28690       3107     OCR  Franz Vogt               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 28771        Tod              n/a               n/a  1632-08-03  1632-08-03
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28771  ...        n/a       n/a      n/a               n/a
#
#                            additional_info comment info_dump  \
# 28771  + 3.8.1632 während seines Rektorats     n/a       n/a
#
#                                                   source source_site  \
# 28771   Praetorius, Professoren, S.98; \n Reg. Univ. ...         n/a
#
#       Unnamed: 0
# 28771       8258
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID   pers_name alternative_names  \
# 28771        28690       3107     OCR  Franz Vogt               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 28771        Tod              n/a               n/a  1632-08-03  1632-08-03
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28771  ...        n/a       n/a      n/a               n/a
#
#                            additional_info comment info_dump  \
# 28771  + 3.8.1632 während seines Rektorats     n/a       n/a
#
#                                                   source source_site  \
# 28771   Praetorius, Professoren, S.98; \n Reg. Univ. ...         n/a
#
#       Unnamed: 0
# 28771       8258
#
# [1 rows x 23 columns]
# 677
# Only one value found.
# 676
# Only one value found.
# 675
# Only one value found.
# 674
# Only one value found.
# 673
# Only one value found.
# 672
# Only one value found.
# 671
# Only one value found.
# 670
# Only one value found.
# 669
# Only one value found.
# 668
# Only one value found.
# 667
# Only one value found.
# 666
# Only one value found.
# 665
# Only one value found.
# 664
# Only one value found.
# 663
# Only one value found.
# 662
# Kapitularherr
#       Unnamed: 0.1 factoid_ID pers_ID      pers_name alternative_names  \
# 28787        28919       2255     OCR  Stephan Weber               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28787        Tod       1570-07-24               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28787  ...      Mainz       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28787  Kanoniker an St. Viktor in Mainz vom 24.7.1570...     n/a       n/a
#
#                                                   source source_site  \
# 28787   Praetorius, Professoren, S.94; \n Roth, Thüri...         n/a
#
#       Unnamed: 0
# 28787       8487
#
# [1 rows x 23 columns]
#  Dekan
#       Unnamed: 0.1 factoid_ID pers_ID      pers_name alternative_names  \
# 28787        28919       2255     OCR  Stephan Weber               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28787        Tod       1570-07-24               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28787  ...      Mainz       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28787  Kanoniker an St. Viktor in Mainz vom 24.7.1570...     n/a       n/a
#
#                                                   source source_site  \
# 28787   Praetorius, Professoren, S.94; \n Roth, Thüri...         n/a
#
#       Unnamed: 0
# 28787       8487
#
# [1 rows x 23 columns]
# 661
# Only one value found.
# 660
# Only one value found.
# 659
# Only one value found.
# 658
# Only one value found.
# 657
# Only one value found.
# 656
# Only one value found.
# 655
# Only one value found.
# 654
# Only one value found.
# 653
# Only one value found.
# 652
# Only one value found.
# 651
# Vizedom
#       Unnamed: 0.1 factoid_ID pers_ID                 pers_name  \
# 28798        29018       4993     OCR  Franz Gottfried Weinz‚Rl
#
#       alternative_names event_type event_after-date event_before-date  \
# 28798               n/a        Tod              n/a               n/a
#
#       event_start event_end  ...                 place_name  \
# 28798        1771      1771  ...  Vizedomamt Bingen, Bingen
#
#                                     inst_name rel_pers source_quotations  \
# 28798  Kurfürstentum Mainz, Vizedomamt Erfurt      n/a               n/a
#
#                    additional_info comment info_dump  \
# 28798  + 1771 im Vizedomamt Bingen     n/a       n/a
#
#                                                   source source_site  \
# 28798   Praetorius, Professoren, S.133; \n RR I 157v;...         n/a
#
#       Unnamed: 0
# 28798       8586
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID                 pers_name  \
# 28798        29018       4993     OCR  Franz Gottfried Weinz‚Rl
#
#       alternative_names event_type event_after-date event_before-date  \
# 28798               n/a        Tod              n/a               n/a
#
#       event_start event_end  ...                 place_name  \
# 28798        1771      1771  ...  Vizedomamt Bingen, Bingen
#
#                                     inst_name rel_pers source_quotations  \
# 28798  Kurfürstentum Mainz, Vizedomamt Erfurt      n/a               n/a
#
#                    additional_info comment info_dump  \
# 28798  + 1771 im Vizedomamt Bingen     n/a       n/a
#
#                                                   source source_site  \
# 28798   Praetorius, Professoren, S.133; \n RR I 157v;...         n/a
#
#       Unnamed: 0
# 28798       8586
#
# [1 rows x 23 columns]
# 650
# Only one value found.
# 649
# Only one value found.
# 648
# Only one value found.
# 647
# Only one value found.
# 646
# Only one value found.
# 645
# Only one value found.
# 644
# Only one value found.
# 643
# Only one value found.
# 642
# Only one value found.
# 641
# Only one value found.
# 640
# Only one value found.
# 639
# Only one value found.
# 638
# Only one value found.
# 637
# Only one value found.
# 636
# Kapitularherr
#       Unnamed: 0.1 factoid_ID pers_ID           pers_name alternative_names  \
# 28813        29191       3990     OCR  Mercurius Wilthelm               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28813        Tod       1548-06-24               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28813  ...      Mainz       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28813  Kanoniker von St. Viktor in Mainz vom 24.6.154...     n/a       n/a
#
#                                                   source source_site  \
# 28813   Praetorius, Professoren, S.97; \n Hansel, Anh...         n/a
#
#       Unnamed: 0
# 28813       8759
#
# [1 rows x 23 columns]
#  Kantor
#       Unnamed: 0.1 factoid_ID pers_ID           pers_name alternative_names  \
# 28813        29191       3990     OCR  Mercurius Wilthelm               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 28813        Tod       1548-06-24               n/a         n/a       n/a
#
#        ... place_name inst_name rel_pers source_quotations  \
# 28813  ...      Mainz       n/a      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 28813  Kanoniker von St. Viktor in Mainz vom 24.6.154...     n/a       n/a
#
#                                                   source source_site  \
# 28813   Praetorius, Professoren, S.97; \n Hansel, Anh...         n/a
#
#       Unnamed: 0
# 28813       8759
#
# [1 rows x 23 columns]
# 635
# Only one value found.
# 634
# Only one value found.
# 633
# Only one value found.
# 632
# Großherzog
#       Unnamed: 0.1 factoid_ID pers_ID              pers_name  \
# 28817        29244       5045     OCR  Franz Joseph Wittmann
#
#       alternative_names event_type event_after-date event_before-date  \
# 28817               n/a        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name inst_name rel_pers  \
# 28817  1847-06-08  1847-06-08  ...      Mainz       n/a      n/a
#
#       source_quotations                                    additional_info  \
# 28817               n/a  + 8.6.1847 in Mainz als Großherzoglich hessisc...
#
#       comment info_dump                                             source  \
# 28817     n/a       n/a   Prot. phil. Fak., S.242, 256; \n Krämer, S. 6...
#
#       source_site Unnamed: 0
# 28817         n/a       8812
#
# [1 rows x 23 columns]
#  Toter
#       Unnamed: 0.1 factoid_ID pers_ID              pers_name  \
# 28817        29244       5045     OCR  Franz Joseph Wittmann
#
#       alternative_names event_type event_after-date event_before-date  \
# 28817               n/a        Tod              n/a               n/a
#
#       event_start   event_end  ... place_name inst_name rel_pers  \
# 28817  1847-06-08  1847-06-08  ...      Mainz       n/a      n/a
#
#       source_quotations                                    additional_info  \
# 28817               n/a  + 8.6.1847 in Mainz als Großherzoglich hessisc...
#
#       comment info_dump                                             source  \
# 28817     n/a       n/a   Prot. phil. Fak., S.242, 256; \n Krämer, S. 6...
#
#       source_site Unnamed: 0
# 28817         n/a       8812
#
# [1 rows x 23 columns]
# 631
# Only one value found.
# 630
# Only one value found.
# 629
# Only one value found.
# 628
# Only one value found.
# 627
# Only one value found.
# 626
# Only one value found.
# 625
# Only one value found.
# 624
# Only one value found.
# 623
# Only one value found.
# 622
# Only one value found.
# 621
# Only one value found.
# 620
# Only one value found.
# 619
# Only one value found.
# 618
# Only one value found.
# 617
# Only one value found.
# 616
# Only one value found.
# 615
# Only one value found.
# 614
# Only one value found.
# 613
# Only one value found.
# 612
# Only one value found.
# 611
# Only one value found.
# 610
# Only one value found.
# 609
# Only one value found.
# 608
# Only one value found.
# 607
# Only one value found.
# 606
# Only one value found.
# 605
# Only one value found.
# 604
# Only one value found.
# 603
# Only one value found.
# 602
# Only one value found.
# 601
# Only one value found.
# 600
# Only one value found.
# 599
# Only one value found.
# 598
# Only one value found.
# 597
# Only one value found.
# 596
# Only one value found.
# 595
# Only one value found.
# 594
# Only one value found.
# 593
# Only one value found.
# 592
# Only one value found.
# 591
# Only one value found.
# 590
# Only one value found.
# 589
# Only one value found.
# 588
# Only one value found.
# 587
# Only one value found.
# 586
# Only one value found.
# 585
# Only one value found.
# 584
# Only one value found.
# 583
# Only one value found.
# 582
# Only one value found.
# 581
# Only one value found.
# 580
# Only one value found.
# 579
# Only one value found.
# 578
# Only one value found.
# 577
# Only one value found.
# 576
# Only one value found.
# 575
# Only one value found.
# 574
# Only one value found.
# 573
# Only one value found.
# 572
# Only one value found.
# 571
# Only one value found.
# 570
# Only one value found.
# 569
#  	Professor
#       Unnamed: 0.1 factoid_ID pers_ID                            pers_name  \
# 28880         2353       3584     API  Karl Joseph Hieronymus Windischmann
#
#       alternative_names event_type event_after-date event_before-date  \
# 28880               n/a   Vokation              n/a               n/a
#
# ...
#
#       source_site Unnamed: 0
# 29343         n/a       4626
#
# [1 rows x 23 columns]
#  Assessor
#       Unnamed: 0.1 factoid_ID pers_ID         pers_name alternative_names  \
# 29343        25058       6184     OCR  Gottfried Hoffer               n/a
#
#       event_type event_after-date event_before-date event_start   event_end  \
# 29343  Zulassung              n/a               n/a  1738-11-19  1738-11-19
#
#        ... place_name                                   inst_name rel_pers  \
# 29343  ...      Mainz  Universität Mainz, Philosophische Fakultät      n/a
#
#       source_quotations                                    additional_info  \
# 29343               n/a  er wurde am 19.11.1738 zum Concilium majus zug...
#
#       comment info_dump                                             source  \
# 29343     n/a       n/a   Praetorius, Professoren, S.137; \n Cat. Jes. ...
#
#       source_site Unnamed: 0
# 29343         n/a       4626
#
# [1 rows x 23 columns]
# 105
# Only one value found.
# 104
# Only one value found.
# 103
# Only one value found.
# 102
# Only one value found.
# 101
# Only one value found.
# 100
# Only one value found.
# 99
# Only one value found.
# 98
# Only one value found.
# 97
# Only one value found.
# 96
# Only one value found.
# 95
# Only one value found.
# 94
# Only one value found.
# 93
# #
#       Unnamed: 0.1 factoid_ID pers_ID       pers_name alternative_names  \
# 29356        25725       5426     OCR  Andreas Köhler               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 29356  Zulassung       1771-08-23               n/a         n/a       n/a
#
#        ... place_name                                   inst_name rel_pers  \
# 29356  ...      Mainz  Universität Mainz, Philosophische Fakultät      n/a
#
#       source_quotations                                    additional_info  \
# 29356               n/a  Magister, er wurde am 23.8.1771 als Assessor h...
#
#       comment info_dump                                             source  \
# 29356     n/a       n/a   Praetorius, Professoren, S.138; \n Prot. phil...
#
#       source_site Unnamed: 0
# 29356         n/a       5293
#
# [1 rows x 23 columns]
#  Assessor
#       Unnamed: 0.1 factoid_ID pers_ID       pers_name alternative_names  \
# 29356        25725       5426     OCR  Andreas Köhler               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 29356  Zulassung       1771-08-23               n/a         n/a       n/a
#
#        ... place_name                                   inst_name rel_pers  \
# 29356  ...      Mainz  Universität Mainz, Philosophische Fakultät      n/a
#
#       source_quotations                                    additional_info  \
# 29356               n/a  Magister, er wurde am 23.8.1771 als Assessor h...
#
#       comment info_dump                                             source  \
# 29356     n/a       n/a   Praetorius, Professoren, S.138; \n Prot. phil...
#
#       source_site Unnamed: 0
# 29356         n/a       5293
#
# [1 rows x 23 columns]
# 92
# Only one value found.
# 91
# Only one value found.
# 90
# Professor
#       Unnamed: 0.1 factoid_ID pers_ID      pers_name alternative_names  \
# 29359        25824        482     OCR  Michael Kress               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 29359  Zulassung       1744-08-28               n/a         n/a       n/a
#
#        ... place_name           inst_name rel_pers source_quotations  \
# 29359  ...      Mainz  Universität Mainz]      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 29359  am 28.8.1744 erfolgte die Zulassung zur Theolo...     n/a       n/a
#
#                                                   source source_site  \
# 29359   Praetorius, Professoren, S.95, 137; \n RR I 9...         n/a
#
#       Unnamed: 0
# 29359       5392
#
# [1 rows x 23 columns]
#  Assessor
#       Unnamed: 0.1 factoid_ID pers_ID      pers_name alternative_names  \
# 29359        25824        482     OCR  Michael Kress               n/a
#
#       event_type event_after-date event_before-date event_start event_end  \
# 29359  Zulassung       1744-08-28               n/a         n/a       n/a
#
#        ... place_name           inst_name rel_pers source_quotations  \
# 29359  ...      Mainz  Universität Mainz]      n/a               n/a
#
#                                          additional_info comment info_dump  \
# 29359  am 28.8.1744 erfolgte die Zulassung zur Theolo...     n/a       n/a
#
#                                                   source source_site  \
# 29359   Praetorius, Professoren, S.95, 137; \n RR I 9...         n/a
#
#       Unnamed: 0
# 29359       5392
#
# [1 rows x 23 columns]
# 89
# Rektor
#       Unnamed: 0.1 factoid_ID pers_ID                      pers_name  \
# 29360        25831        486     OCR  Johann Martin Ignaz Kreussler
#
#       alternative_names event_type event_after-date event_before-date  \
# 29360          Kreißler  Zulassung       1762-11-03               n/a
#
#       event_start event_end  ...  place_name               inst_name rel_pers  \
# 29360         n/a       n/a  ...  Heidelberg  Universität Heidelberg      n/a
#
#       source_quotations                                    additional_info  \
# 29360               n/a  er wurde am 3.11.1762 als Professor der Logik ...
#
#       comment info_dump                                             source  \
# 29360     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
#
#       source_site Unnamed: 0
# 29360         n/a       5399
#
# [1 rows x 23 columns]
#  Professor
#       Unnamed: 0.1 factoid_ID pers_ID                      pers_name  \
# 29360        25831        486     OCR  Johann Martin Ignaz Kreussler
#
#       alternative_names event_type event_after-date event_before-date  \
# 29360          Kreißler  Zulassung       1762-11-03               n/a
#
#       event_start event_end  ...  place_name               inst_name rel_pers  \
# 29360         n/a       n/a  ...  Heidelberg  Universität Heidelberg      n/a
#
#       source_quotations                                    additional_info  \
# 29360               n/a  er wurde am 3.11.1762 als Professor der Logik ...
#
#       comment info_dump                                             source  \
# 29360     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
#
#       source_site Unnamed: 0
# 29360         n/a       5399
#
# [1 rows x 23 columns]
#  Dekan
#       Unnamed: 0.1 factoid_ID pers_ID                      pers_name  \
# 29360        25831        486     OCR  Johann Martin Ignaz Kreussler
#
#       alternative_names event_type event_after-date event_before-date  \
# 29360          Kreißler  Zulassung       1762-11-03               n/a
#
#       event_start event_end  ...  place_name               inst_name rel_pers  \
# 29360         n/a       n/a  ...  Heidelberg  Universität Heidelberg      n/a
#
#       source_quotations                                    additional_info  \
# 29360               n/a  er wurde am 3.11.1762 als Professor der Logik ...
#
#       comment info_dump                                             source  \
# 29360     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
#
#       source_site Unnamed: 0
# 29360         n/a       5399
#
# [1 rows x 23 columns]
# 88
# Only one value found.
# 87
# Only one value found.
# 86
# Only one value found.
# 85
# Only one value found.
# 84
# Only one value found.
# 83
# Only one value found.
# 82
# Only one value found.
# 81
# Only one value found.
# 80
# Only one value found.
# 79
# Only one value found.
# 78
# Only one value found.
# 77
# Only one value found.
# 76
# Only one value found.
# 75
# Only one value found.
# 74
# Only one value found.
# 73
# Only one value found.
# 72
# Only one value found.
# 71
# Only one value found.
# 70
# Only one value found.
# 69
# Only one value found.
# 68
# Only one value found.
# 67
# Only one value found.
# 66
# Only one value found.
# 65
# Only one value found.
# 64
# Only one value found.
# 63
# Only one value found.
# 62
# Only one value found.
# 61
# Only one value found.
# 60
# Only one value found.
# 59
# Only one value found.
# 58
# Only one value found.
# 57
# Only one value found.
# 56
# Only one value found.
# 55
# Only one value found.
# 54
# Only one value found.
# 53
# Only one value found.
# 52
# Only one value found.
# 51
# Only one value found.
# 50
# Only one value found.
# 49
# Only one value found.
# 48
# Only one value found.
# 47
# Only one value found.
# 46
# Only one value found.
# 45
# Only one value found.
# 44
# Only one value found.
# 43
# Only one value found.
# 42
# Only one value found.
# 41
# Only one value found.
# 40
# Only one value found.
# 39
# Only one value found.
# 38
# Only one value found.
# 37
# Only one value found.
# 36
# Only one value found.
# 35
# Only one value found.
# 34
# Only one value found.
# 33
# Only one value found.
# 32
# Only one value found.
# 31
# Only one value found.
# 30
# Only one value found.
# 29
# Only one value found.
# 28
# Only one value found.
# 27
# Only one value found.
# 26
# Only one value found.
# 25
# Only one value found.
# 24
# Only one value found.
# 23
# Only one value found.
# 22
# Only one value found.
# 21
# Only one value found.
# 20
# Only one value found.
# 19
# Only one value found.
# 18
# Only one value found.
# 17
# Only one value found.
# 16
# Only one value found.
# 15
# Only one value found.
# 14
# Only one value found.
# 13
# Only one value found.
# 12
# Only one value found.
# 11
# Only one value found.
# 10
# Only one value found.
# 9
# Only one value found.
# 8
# Only one value found.
# 7
# Only one value found.
# 6
# Only one value found.
# 5
# Only one value found.
# 4
# Only one value found.
# 3
# Only one value found.
# 2
# Only one value found.
# 1
# Only one value found.
#      Unnamed: 0.1 factoid_ID pers_ID                      pers_name  \
# 0            1974        932     API          Matthias Joseph Hagen
# 1            1974        932     API          Matthias Joseph Hagen
# 2            2341        432     API  Franz Anton Chrysostomus Dürr
# 3            2341        432     API  Franz Anton Chrysostomus Dürr
# 4            3288       2478     OCR                    Simon Bagen
# ...           ...        ...     ...                            ...
# 6275        25824        482     OCR                  Michael Kress
# 6276        25824        482     OCR                  Michael Kress
# 6277        25831        486     OCR  Johann Martin Ignaz Kreussler
# 6278        25831        486     OCR  Johann Martin Ignaz Kreussler
# 6279        25831        486     OCR  Johann Martin Ignaz Kreussler
#
#      alternative_names   event_type event_after-date event_before-date  \
# 0                  n/a  Amtsantritt              n/a               n/a
# 1                  n/a  Amtsantritt              n/a               n/a
# 2                  n/a  Amtsantritt              n/a               n/a
# 3                  n/a  Amtsantritt              n/a               n/a
# 4                  n/a  Amtsantritt              n/a               n/a
# ...                ...          ...              ...               ...
# 6275               n/a    Zulassung       1744-08-28               n/a
# 6276               n/a    Zulassung       1744-08-28               n/a
# 6277          Kreißler    Zulassung       1762-11-03               n/a
# 6278          Kreißler    Zulassung       1762-11-03               n/a
# 6279          Kreißler    Zulassung       1762-11-03               n/a
#
#            event_start         event_end  ...   place_name  \
# 0           1791-01-01        1814-04-11  ...          n/a
# 1           1791-01-01        1814-04-11  ...          n/a
# 2           1759-01-01               n/a  ...          n/a
# 3           1759-01-01               n/a  ...          n/a
# 4     1523, 1524, 1529  1523, 1524, 1529  ...  Köln, Mainz
# ...                ...               ...  ...          ...
# 6275               n/a               n/a  ...        Mainz
# 6276               n/a               n/a  ...        Mainz
# 6277               n/a               n/a  ...   Heidelberg
# 6278               n/a               n/a  ...   Heidelberg
# 6279               n/a               n/a  ...   Heidelberg
#
#                                  inst_name  \
# 0                                      n/a
# 1                                      n/a
# 2     Stiftung Mainzer Universitätsfonds\n
# 3     Stiftung Mainzer Universitätsfonds\n
# 4       Universität Köln/Universität Mainz
# ...                                    ...
# 6275                    Universität Mainz]
# 6276                    Universität Mainz]
# 6277                Universität Heidelberg
# 6278                Universität Heidelberg
# 6279                Universität Heidelberg
#
#                                                rel_pers source_quotations  \
# 0                                                   n/a               n/a
# 1                                                   n/a               n/a
# 2                                                   n/a               n/a
# 3                                                   n/a               n/a
# 4      V: Peter B., seine Mutter, eine Mainzerin, ka...               n/a
# ...                                                 ...               ...
# 6275                                                n/a               n/a
# 6276                                                n/a               n/a
# 6277                                                n/a               n/a
# 6278                                                n/a               n/a
# 6279                                                n/a               n/a
#
#                                         additional_info comment info_dump  \
# 0                                                   n/a     n/a       n/a
# 1                                                   n/a     n/a       n/a
# 2                  Stiftung Mainzer Universitätsfonds\n     n/a       n/a
# 3                  Stiftung Mainzer Universitätsfonds\n     n/a       n/a
# 4     aus der Diözese Köln * 1523 oder 1524; V: Pete...     n/a       n/a
# ...                                                 ...     ...       ...
# 6275  am 28.8.1744 erfolgte die Zulassung zur Theolo...     n/a       n/a
# 6276  am 28.8.1744 erfolgte die Zulassung zur Theolo...     n/a       n/a
# 6277  er wurde am 3.11.1762 als Professor der Logik ...     n/a       n/a
# 6278  er wurde am 3.11.1762 als Professor der Logik ...     n/a       n/a
# 6279  er wurde am 3.11.1762 als Professor der Logik ...     n/a       n/a
#
#                                                  source  \
# 0                                               ProfAPI
# 1                                               ProfAPI
# 2                                               ProfAPI
# 3                                               ProfAPI
# 4      Praetorius, Professoren, S.97; \n Dürr, Bl.34...
# ...                                                 ...
# 6275   Praetorius, Professoren, S.95, 137; \n RR I 9...
# 6276   Praetorius, Professoren, S.95, 137; \n RR I 9...
# 6277   Praetorius, Professoren, S.138; \n Cat. Jes. ...
# 6278   Praetorius, Professoren, S.138; \n Cat. Jes. ...
# 6279   Praetorius, Professoren, S.138; \n Cat. Jes. ...
#
#                                             source_site Unnamed: 0
# 0     http://gutenberg-biographics.ub.uni-mainz.de/i...        752
# 1     http://gutenberg-biographics.ub.uni-mainz.de/i...        752
# 2     http://gutenberg-biographics.ub.uni-mainz.de/i...       1119
# 3     http://gutenberg-biographics.ub.uni-mainz.de/i...       1119
# 4                                                   n/a       2066
# ...                                                 ...        ...
# 6275                                                n/a       5392
# 6276                                                n/a       5392
# 6277                                                n/a       5399
# 6278                                                n/a       5399
# 6279                                                n/a       5399
#
# [6280 rows x 23 columns]

# %% [markdown]
# In **step 3**, we write all data to a new EXCEL file.

# %%
from pandas.tseries.offsets import FY5253
# write amended rows to existing data frame for further processing

f_to_add.append(df2)
f_to_add.append(df_split)

df3 = pd.concat(f_to_add, axis=0, ignore_index=True, sort=False)

print(len(df3))

display(df3)

workbook=directory+'FACTOIDS_consolidated/Factoid_PROFS_consolidation_STEP3_events-split.xlsx'
print(workbook)
writer = pd.ExcelWriter(workbook, engine='xlsxwriter') # create a Pandas Excel writer using XlsxWriter as the engine.
df3.to_excel(writer, sheet_name='FactProfSplit') # Convert the dataframe to an XlsxWriter Excel object.
writer.save() # Close the Pandas Excel writer and output the Excel file.
print("Done.")
# Out:
# 35729
#       Unnamed: 0.1 factoid_ID pers_ID                             pers_name  \
# 0             1222        286     API              Wendelin Wendelin Dietes
# 1             1223        455     API  Matthäus Anton Chrysostomus Eberwein
# 2             1225        809     API                 Bertold Georg Gothelp
# 3             1228       2617     API            Alexander Günther Samhaber
# 4             1233       3462     API                Damian Friedrich Boost
# ...            ...        ...     ...                                   ...
# 35724        25824        482     OCR                         Michael Kress
# 35725        25824        482     OCR                         Michael Kress
# 35726        25831        486     OCR         Johann Martin Ignaz Kreussler
# 35727        25831        486     OCR         Johann Martin Ignaz Kreussler
# 35728        25831        486     OCR         Johann Martin Ignaz Kreussler
#
#       alternative_names         event_type event_after-date event_before-date  \
# 0                   n/a  Funktionsausübung              n/a               n/a
# 1                   n/a        Amtsantritt              n/a               n/a
# 2                   n/a        Amtsantritt              n/a               n/a
# 3                   n/a        Amtsantritt              n/a               n/a
# 4                   n/a        Amtsantritt              n/a               n/a
# ...                 ...                ...              ...               ...
# 35724               n/a          Zulassung       1744-08-28               n/a
# 35725               n/a          Zulassung       1744-08-28               n/a
# 35726          Kreißler          Zulassung       1762-11-03               n/a
# 35727          Kreißler          Zulassung       1762-11-03               n/a
# 35728          Kreißler          Zulassung       1762-11-03               n/a
#
#       event_start   event_end  ...     place_name  \
# 0      1616-01-01  1646-12-31  ...  Aschaffenburg
# 1             n/a         n/a  ...          Mainz
# 2             n/a         n/a  ...          Mainz
# 3             n/a         n/a  ...            n/a
# 4      1779-02-03  1779-02-03  ...            n/a
# ...           ...         ...  ...            ...
# 35724         n/a         n/a  ...          Mainz
# 35725         n/a         n/a  ...          Mainz
# 35726         n/a         n/a  ...     Heidelberg
# 35727         n/a         n/a  ...     Heidelberg
# 35728         n/a         n/a  ...     Heidelberg
#
#                                                inst_name rel_pers  \
# 0      Kollegiatstift St. Peter und Alexander Aschaff...      n/a
# 1                                       St. Viktor Mainz      n/a
# 2                                        St. Peter Mainz      n/a
# 3                                        Augustinerorden      n/a
# 4                                        Concilium Majus      n/a
# ...                                                  ...      ...
# 35724                                 Universität Mainz]      n/a
# 35725                                 Universität Mainz]      n/a
# 35726                             Universität Heidelberg      n/a
# 35727                             Universität Heidelberg      n/a
# 35728                             Universität Heidelberg      n/a
#
#       source_quotations                                    additional_info  \
# 0                   n/a  \nLektoratspräbende Stift St. Peter und Alexan...
# 1                   n/a     \nLektoratspräbende Stift St. Viktor (Mainz)\n
# 2                   n/a                                                n/a
# 3                   n/a                                \nAugustinerorden\n
# 4                   n/a                                \nConcilium majus\n
# ...                 ...                                                ...
# 35724               n/a  am 28.8.1744 erfolgte die Zulassung zur Theolo...
# 35725               n/a  am 28.8.1744 erfolgte die Zulassung zur Theolo...
# 35726               n/a  er wurde am 3.11.1762 als Professor der Logik ...
# 35727               n/a  er wurde am 3.11.1762 als Professor der Logik ...
# 35728               n/a  er wurde am 3.11.1762 als Professor der Logik ...
#
#       comment info_dump                                             source  \
# 0         n/a       n/a                                            ProfAPI
# 1         n/a       n/a                                            ProfAPI
# 2         n/a       n/a                                            ProfAPI
# 3         n/a       n/a                                            ProfAPI
# 4         n/a       n/a                                            ProfAPI
# ...       ...       ...                                                ...
# 35724     n/a       n/a   Praetorius, Professoren, S.95, 137; \n RR I 9...
# 35725     n/a       n/a   Praetorius, Professoren, S.95, 137; \n RR I 9...
# 35726     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
# 35727     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
# 35728     n/a       n/a   Praetorius, Professoren, S.138; \n Cat. Jes. ...
#
#                                              source_site Unnamed: 0
# 0      http://gutenberg-biographics.ub.uni-mainz.de/i...          0
# 1      http://gutenberg-biographics.ub.uni-mainz.de/i...          1
# 2      http://gutenberg-biographics.ub.uni-mainz.de/i...          3
# 3      http://gutenberg-biographics.ub.uni-mainz.de/i...          6
# 4      http://gutenberg-biographics.ub.uni-mainz.de/i...         11
# ...                                                  ...        ...
# 35724                                                n/a       5392
# 35725                                                n/a       5392
# 35726                                                n/a       5399
# 35727                                                n/a       5399
# 35728                                                n/a       5399
#
# [35729 rows x 23 columns]
# /content/drive/My Drive/Colab_DigiKAR/FACTOIDS_consolidated/Factoid_PROFS_consolidation_STEP3_events-split.xlsx
# Done.

# %% [markdown]
# Check the output files and repeat process if necessary.
#
# Script by Monika Barget, Maastricht/Mainz
#
# March 2023
