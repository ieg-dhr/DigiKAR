# %% [markdown]
# This is a script for consolidating factoid lists in AP3.
#
# The package mainly uses the Pandas package in Python to read and manipulate EXCEL data as DataFrames. DataFrames are 2-dimensional data representations in rows and columns. They can be written to different file formats such as CSV, EXCEL, JSON or RDF.
#
# First of all, we need to connect this Colab notebook with your Google Drive and define the directory for input and output data.

# %%
## mount drive
from google.colab import drive
drive.mount("/content/drive")
directory="/content/drive/My Drive/Colab_DigiKAR/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# In the second step, we have to install additional Packages needed for working with CSV, EXCEL and DataFrames.

# %%
## install packages that are not part of Python's standard distribution

# !pip install xlsxwriter
# !pip install pandas
# !pip install numpy
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)

# %% [markdown]
# In **step 1**, we can import the packages to the script and load our data. Before merging the input files, names will be normalised as some have access spaces, capitalised surnames, or inverted first and last names.
#
# The combined data will be written to a new dataframe and displayed.

# %%
import xlsxwriter
import csv
import pandas as pd
from pandas import DataFrame
import numpy as np
import os
import re

# path to input files

factoid_paths=["https://github.com/ieg-dhr/DigiKAR/raw/main/Sample%20Data/FactoidList_1756er_Staatskalender_Meta_final_TEST-MB_FS0.xlsx",
               "https://github.com/ieg-dhr/DigiKAR/raw/main/Sample%20Data/FactoidList_1756er_Staatskalender_Meta_final_TEST-MB_FS1.xlsx",
               "https://github.com/ieg-dhr/DigiKAR/raw/main/Sample%20Data/FactoidList_1756er_Staatskalender_Meta_final_TEST-MB_FS2.xlsx",
               "https://github.com/ieg-dhr/DigiKAR/raw/main/Sample%20Data/FactoidList_1756er_Staatskalender_Meta_final_TEST-MB_FS3.xlsx",
               "https://github.com/ieg-dhr/DigiKAR/raw/main/Sample%20Data/FactoidList_1756er_Staatskalender_Meta_final_TEST-MB_FS4.xlsx",
               "https://github.com/ieg-dhr/DigiKAR/raw/main/Sample%20Data/FactoidList_Erfassung_Erfurt_Master_2022-11-11_Kopie.xlsx"
               ]

# define dataframe for final output

f_to_add=[]

# structure of input files

# obligatory columns in valid factoid list

# read all data frames from path

frame_list=[]
for file in factoid_paths:
    df = pd.read_excel(file, index_col=None, dtype=str) # axis=1, sort=False sheet_name='FactoidList'
    df = df.fillna("n/a") # replace empty fields for string
    df_length=len(df)
    frame_list.append(df)

f = pd.concat(frame_list, axis=0, ignore_index=True, sort=False)

print("There are ", len(f), "items in your DataFrame!")

# delete all duplicate rows with exact matches

f_unique=f.drop_duplicates()
print("Your DataFrame has now ", len(f_unique), "items with at least one unique cell." )

# add columns missing according to factoid model

column_names = ["factoid_ID",
                "pers_ID",
                "pers_name",
                "alternative_names",
                "event_type",
                "event_after-date",
                "event_before-date",
                "event_start",
                "event_end",
                "event_date",
                "pers_title",
                "pers_function",
                "place_name",
                "inst_name",
                "rel_pers",
                "source_quotations",
                "additional_info",
                "comment",
                "info_dump",
                "source_combined",
                "event_value", # add more potential categorisations if needed
                "source",
                "source_site"]

df2 = f_unique.reindex(columns=column_names)

# populate some of the empty columns with data

df2.loc[:, "event_end"] = df2["event_start"]
#df2.loc[:, "event_type"] = ["Funktionsausübung"] * 37400 # add new column with standard event if column is completely absent!
df2["event_type"] = df2["event_type"].replace({'n/a':'Funktionsausübung'}) # add standard event in places where no other event is indicated!
df2.fillna('n/a', inplace=True) # fill remaining blanks with string to ensure that all cells can be processed in the same way!
df2['source_combined'] = df2['source'].astype(str) + ': ' + df2['source_site'].astype(str)

print("Done.")

# rename dataframe for next step

display(df2)
# Out:
# There are  40080 items in your DataFrame!
# Your DataFrame has now  37400 items with at least one unique cell.
# Done.
#            factoid_ID pers_ID                          pers_name  \
# 0           Stk_00010       9         Johann Werner von Vorstern
# 1           Stk_00052       9         Johann Werner von Vorstern
# 2           Stk_00087       9         Johann Werner von Vorstern
# 3           Stk_00125       9         Johann Werner von Vorstern
# 4           Stk_00170       9          Johann Werner von Vorster
# ...               ...     ...                                ...
# 40075  Erffurt_006271      19  Karl Theodor Freiherr von Dalberg
# 40076  Erffurt_006272      19  Karl Theodor Freiherr von Dalberg
# 40077  Erffurt_006273      19  Karl Theodor Freiherr von Dalberg
# 40078  Erffurt_006274      19  Karl Theodor Freiherr von Dalberg
# 40079  Erffurt_006275      19  Karl Theodor Freiherr von Dalberg
#
#                                        alternative_names  \
# 0                                                    n/a
# 1                                                    n/a
# 2                                                    n/a
# 3                                                    n/a
# 4                                                    n/a
# ...                                                  ...
# 40075  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 40076  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 40077  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 40078  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 40079  Karl Theodor Anton Maria Reichsfreiherr von Da...
#
#                      event_type event_after-date event_before-date  \
# 0             Funktionsausübung              n/a               n/a
# 1             Funktionsausübung              n/a               n/a
# 2             Funktionsausübung              n/a               n/a
# 3             Funktionsausübung              n/a               n/a
# 4             Funktionsausübung              n/a               n/a
# ...                         ...              ...               ...
# 40075                     Weihe              n/a               n/a
# 40076                     Weihe              n/a               n/a
# 40077  Funktionsausübung_Beginn              n/a               n/a
# 40078    Funktionsausübung_Ende              n/a              1814
# 40079                       Tod              n/a               n/a
#
#       event_start   event_end event_date  ...  \
# 0      1739-00-00  1739-00-00        n/a  ...
# 1      1740-00-00  1740-00-00        n/a  ...
# 2      1741-00-00  1741-00-00        n/a  ...
# 3      1742-00-00  1742-00-00        n/a  ...
# 4      1744-00-00  1744-00-00        n/a  ...
# ...           ...         ...        ...  ...
# 40075  1788-02-03  1788-02-03        n/a  ...
# 40076  1788-08-31  1788-08-31        n/a  ...
# 40077        1810        1810        n/a  ...
# 40078         n/a         n/a        n/a  ...
# 40079  1817-02-10  1817-02-10        n/a  ...
#
#                              inst_name rel_pers  \
# 0      Hofrat / Regierung, adlige Bank      n/a
# 1      Hofrat / Regierung, adlige Bank      n/a
# 2      Hofrat / Regierung, adlige Bank      n/a
# 3      Hofrat / Regierung, adlige Bank      n/a
# 4      Hofrat / Regierung, adlige Bank      n/a
# ...                                ...      ...
# 40075                              n/a      n/a
# 40076                              n/a      n/a
# 40077          Großherzogtum Frankfurt      n/a
# 40078          Großherzogtum Frankfurt      n/a
# 40079                              n/a      n/a
#
#                                        source_quotations additional_info  \
# 0                                 Hof- und Regierungsrat             n/a
# 1                                 Hof- und Regierungsrat             n/a
# 2                                 Hof- und Regierungsrat             n/a
# 3                                 Hof- und Regierungsrat             n/a
# 4                         Hof- und Regierungsrat / S. 33             n/a
# ...                                                  ...             ...
# 40075                                                n/a             n/a
# 40076  Ernennung zum Titularerzbischof von Tarsus am ...             n/a
# 40077       "ohne Beziehung zu seiner geistlichen Würde"             n/a
# 40078                                                n/a             n/a
# 40079                                                n/a             n/a
#
#       comment info_dump        source_combined event_value            source  \
# 0         n/a       n/a          Stk_1740B: 44         n/a         Stk_1740B
# 1         n/a       n/a           Stk_1741: 45         n/a          Stk_1741
# 2         n/a       n/a           Stk_1742: 38         n/a          Stk_1742
# 3         n/a       n/a           Stk_1743: 37         n/a          Stk_1743
# 4         n/a       n/a           Stk_1745: 39         n/a          Stk_1745
# ...       ...       ...                    ...         ...               ...
# 40075     n/a       n/a  Gatz1983:Dalberg: 110         n/a  Gatz1983:Dalberg
# 40076     n/a       n/a  Gatz1983:Dalberg: 110         n/a  Gatz1983:Dalberg
# 40077     n/a       n/a  Gatz1983:Dalberg: 112         n/a  Gatz1983:Dalberg
# 40078     n/a       n/a  Gatz1983:Dalberg: 112         n/a  Gatz1983:Dalberg
# 40079     n/a       n/a  Gatz1983:Dalberg: 112         n/a  Gatz1983:Dalberg
#
#       source_site
# 0              44
# 1              45
# 2              38
# 3              37
# 4              39
# ...           ...
# 40075         110
# 40076         110
# 40077         112
# 40078         112
# 40079         112
#
# [37400 rows x 23 columns]

# %%
# Merge input dataframe with dfs containing person IDs and geocoding

## Read person IDs from Github
## columns: pers_ID_MB, pers_name, alternative_names, Unnamed: 4, name_new_fs, pers_ID_FS,poi, pers_name_corr, freq
infile1="https://github.com/ieg-dhr/DigiKAR/raw/main/OntologyFiles/Factoid_PersonNames_merged.xlsx" # has to contain pers_name column!
person_df = pd.read_excel(infile1)

## Read geocoding from Github
infile2="https://github.com/ieg-dhr/DigiKAR/raw/main/OntologyFiles/Ortsontologie_Geocoded_extract.xlsx" # has to contain place_name column!
geo_df = pd.read_excel(infile2).drop_duplicates(subset=['place_name'])

## Merge input dataframe horizontally
# keeping only rows with common values in both dataframes but dropping rows with uncommon values

merged_df1 = pd.merge(df2, geo_df, on='place_name', how="left")
merged_df2 = pd.merge(merged_df1, person_df, on='pers_name', how="left")

display(merged_df1)
# Out:
#            factoid_ID pers_ID                          pers_name  \
# 0           Stk_00010       9         Johann Werner von Vorstern
# 1           Stk_00052       9         Johann Werner von Vorstern
# 2           Stk_00087       9         Johann Werner von Vorstern
# 3           Stk_00125       9         Johann Werner von Vorstern
# 4           Stk_00170       9          Johann Werner von Vorster
# ...               ...     ...                                ...
# 37395  Erffurt_006271      19  Karl Theodor Freiherr von Dalberg
# 37396  Erffurt_006272      19  Karl Theodor Freiherr von Dalberg
# 37397  Erffurt_006273      19  Karl Theodor Freiherr von Dalberg
# 37398  Erffurt_006274      19  Karl Theodor Freiherr von Dalberg
# 37399  Erffurt_006275      19  Karl Theodor Freiherr von Dalberg
#
#                                        alternative_names  \
# 0                                                    n/a
# 1                                                    n/a
# 2                                                    n/a
# 3                                                    n/a
# 4                                                    n/a
# ...                                                  ...
# 37395  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 37396  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 37397  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 37398  Karl Theodor Anton Maria Reichsfreiherr von Da...
# 37399  Karl Theodor Anton Maria Reichsfreiherr von Da...
#
#                      event_type event_after-date event_before-date  \
# 0             Funktionsausübung              n/a               n/a
# 1             Funktionsausübung              n/a               n/a
# 2             Funktionsausübung              n/a               n/a
# 3             Funktionsausübung              n/a               n/a
# 4             Funktionsausübung              n/a               n/a
# ...                         ...              ...               ...
# 37395                     Weihe              n/a               n/a
# 37396                     Weihe              n/a               n/a
# 37397  Funktionsausübung_Beginn              n/a               n/a
# 37398    Funktionsausübung_Ende              n/a              1814
# 37399                       Tod              n/a               n/a
#
#       event_start   event_end event_date  ...                 Source  \
# 0      1739-00-00  1739-00-00        n/a  ...  Universitätsmatrikeln
# 1      1740-00-00  1740-00-00        n/a  ...  Universitätsmatrikeln
# 2      1741-00-00  1741-00-00        n/a  ...  Universitätsmatrikeln
# 3      1742-00-00  1742-00-00        n/a  ...  Universitätsmatrikeln
# 4      1744-00-00  1744-00-00        n/a  ...  Universitätsmatrikeln
# ...           ...         ...        ...  ...                    ...
# 37395  1788-02-03  1788-02-03        n/a  ...                    NaN
# 37396  1788-08-31  1788-08-31        n/a  ...                    NaN
# 37397        1810        1810        n/a  ...                    NaN
# 37398         n/a         n/a        n/a  ...                    NaN
# 37399  1817-02-10  1817-02-10        n/a  ...                    NaN
#
#       addresses_full        ids geonames address latitudes longitudes  \
# 0      Mainz, Europe  2874225.0            Mainz  49.98419     8.2791
# 1      Mainz, Europe  2874225.0            Mainz  49.98419     8.2791
# 2      Mainz, Europe  2874225.0            Mainz  49.98419     8.2791
# 3      Mainz, Europe  2874225.0            Mainz  49.98419     8.2791
# 4      Mainz, Europe  2874225.0            Mainz  49.98419     8.2791
# ...              ...        ...              ...       ...        ...
# 37395            NaN        NaN              NaN       NaN        NaN
# 37396            NaN        NaN              NaN       NaN        NaN
# 37397            NaN        NaN              NaN       NaN        NaN
# 37398            NaN        NaN              NaN       NaN        NaN
# 37399            NaN        NaN              NaN       NaN        NaN
#
#              lat       lng  Google address       NaN
# 0      49.992862  8.247253  Mainz, Germany  0.000173
# 1      49.992862  8.247253  Mainz, Germany  0.000173
# 2      49.992862  8.247253  Mainz, Germany  0.000173
# 3      49.992862  8.247253  Mainz, Germany  0.000173
# 4      49.992862  8.247253  Mainz, Germany  0.000173
# ...          ...       ...             ...       ...
# 37395        NaN       NaN             NaN       NaN
# 37396        NaN       NaN             NaN       NaN
# 37397        NaN       NaN             NaN       NaN
# 37398        NaN       NaN             NaN       NaN
# 37399        NaN       NaN             NaN       NaN
#
# [37400 rows x 36 columns]

# %% [markdown]
# In **step 2**, we reconstruct end dates for successive start dates. The data are automatically aggregated using Python's `groupby` function. If the results are too narrow or too broad, please change the aggregation rules below!

# %%
# Group the dataframe and aggregate the start and end dates
# code updated after problem with merged columns
# see discussion on Stackoverflow: https://stackoverflow.com/questions/76558443/column-remains-empty-when-using-map-with-dictionary-in-pandas-dataframe/76558586#76558586

grouped_df = merged_df2.groupby(['pers_ID_FS', 'event_type', "pers_function", "pers_title", "inst_name", "place_name"], as_index=False).agg(
                                                         {'event_start': 'min',
                                                          "event_after-date":'min',
                                                          "event_before-date":'max',
                                                          "event_end":'max',
                                                          "factoid_ID":list,
                                                          "pers_ID_MB":list,
                                                          "pers_name":list,
                                                          #"alternative_names":list,
                                                          "Unnamed: 4":list,
                                                          "name_new_fs":list,
                                                          "pers_name_corr":list,
                                                          "rel_pers":list,
                                                          "source_quotations":list,
                                                          "additional_info":list,
                                                          "comment":list,
                                                          "info_dump":list,
                                                          "source_combined":list,
                                                          "event_value":list,
                                                          "place_name":list,
                                                          #"address":list,
                                                          "addresses_full":list,
                                                          "ids":list,
                                                          "geonames address":list,
                                                          "latitudes":list,
                                                          "longitudes":list,
                                                          "lat":list,
                                                          "lng":list,
                                                          "Google address":list
                                                          })

display(grouped_df)
# Out:
#      pers_ID_FS         event_type            pers_function      pers_title  \
# 0             1  Funktionsausübung        Kriegszahlmeister             n/a
# 1            10           Aufnahme                   Bürger             n/a
# 2            10  Funktionsausübung                Fabrikant             n/a
# 3            10  Funktionsausübung  Kammer- und Zahlmeister             n/a
# 4            10  Funktionsausübung                Kammerrat             n/a
# ...         ...                ...                      ...             ...
# 4638      P-002                n/a                 Syndikus  Lic. iur. utr.
# 4639      P-002                n/a                 Syndikus             n/a
# 4640      P-002                n/a                      n/a   Dr. iur. utr.
# 4641      P-002                n/a                      n/a  Lic. iur. utr.
# 4642          X             Geburt                     Kind             n/a
#
#                    inst_name event_start event_after-date event_before-date  \
# 0           Kammer zu Erfurt  1781-00-00              n/a               n/a
# 1     Bürgerschaft zu Erfurt  1747-02-20              n/a               n/a
# 2                 Wollfabrik        0000             1750              1759
# 3           Kammer zu Erfurt  1766-00-00              n/a               n/a
# 4           Kammer zu Erfurt  1766-00-00              n/a               n/a
# ...                      ...         ...              ...               ...
# 4638       Universität Mainz  1746-00-00              n/a               n/a
# 4639       Universität Mainz  1742-00-00              n/a               n/a
# 4640                     n/a  1755-00-00              n/a               n/a
# 4641                     n/a  1740-00-00              n/a               n/a
# 4642                     n/a  16XX-00-00              n/a               n/a
#
#        event_end                                         factoid_ID  ...  \
# 0     1781-00-00                                   [Erffurt_000158]  ...
# 1     1747-02-20                                   [Erffurt_000416]  ...
# 2           0000                   [Erffurt_004934, Erffurt_004934]  ...
# 3     1766-00-00                   [Erffurt_000152, Erffurt_000152]  ...
# 4     1766-00-00                   [Erffurt_000151, Erffurt_000151]  ...
# ...          ...                                                ...  ...
# 4638  1753-00-00  [Stk_31736, Stk_31738, Stk_31740, Stk_31742, S...  ...
# 4639  1756-00-00  [Stk_31732, Stk_31733, Stk_31734, Stk_31735, S...  ...
# 4640  1756-00-00       [Stk_31766, Stk_31767, Stk_31766, Stk_31767]  ...
# 4641  1753-00-00  [Stk_31757, Stk_31758, Stk_31759, Stk_31760, S...  ...
# 4642  16XX-00-00                                   [Erffurt_000836]  ...
#
#                                             event_value  \
# 0                                                 [n/a]
# 1                                                 [n/a]
# 2                                            [n/a, n/a]
# 3                                            [n/a, n/a]
# 4                                            [n/a, n/a]
# ...                                                 ...
# 4638  [n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, ...
# 4639  [n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, ...
# 4640                               [n/a, n/a, n/a, n/a]
# 4641  [n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, ...
# 4642                                              [n/a]
#
#                                              place_name  \
# 0                                              [Erfurt]
# 1                                              [Erfurt]
# 2                                      [Erfurt, Erfurt]
# 3                                      [Erfurt, Erfurt]
# 4                                      [Erfurt, Erfurt]
# ...                                                 ...
# 4638  [Mainz, Mainz, Mainz, Mainz, Mainz, Mainz, Mai...
# 4639  [Mainz, Mainz, Mainz, Mainz, Mainz, Mainz, Mai...
# 4640                               [n/a, n/a, n/a, n/a]
# 4641  [n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, n/a, ...
# 4642                                           [Erfurt]
#
#                                          addresses_full  \
# 0                                      [Erfurt, Europe]
# 1                                      [Erfurt, Europe]
# 2                      [Erfurt, Europe, Erfurt, Europe]
# 3                      [Erfurt, Europe, Erfurt, Europe]
# 4                      [Erfurt, Europe, Erfurt, Europe]
# ...                                                 ...
# 4638  [Mainz, Europe, Mainz, Europe, Mainz, Europe, ...
# 4639  [Mainz, Europe, Mainz, Europe, Mainz, Europe, ...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                   [Erfurt, Europe]
#
#                                                     ids  \
# 0                                           [2929670.0]
# 1                                           [2929670.0]
# 2                                [2929670.0, 2929670.0]
# 3                                [2929670.0, 2929670.0]
# 4                                [2929670.0, 2929670.0]
# ...                                                 ...
# 4638  [2874225.0, 2874225.0, 2874225.0, 2874225.0, 2...
# 4639  [2874225.0, 2874225.0, 2874225.0, 2874225.0, 2...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                        [2929670.0]
#
#                                        geonames address  \
# 0                                              [Erfurt]
# 1                                              [Erfurt]
# 2                                      [Erfurt, Erfurt]
# 3                                      [Erfurt, Erfurt]
# 4                                      [Erfurt, Erfurt]
# ...                                                 ...
# 4638  [Mainz, Mainz, Mainz, Mainz, Mainz, Mainz, Mai...
# 4639  [Mainz, Mainz, Mainz, Mainz, Mainz, Mainz, Mai...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                           [Erfurt]
#
#                                               latitudes  \
# 0                                             [50.9787]
# 1                                             [50.9787]
# 2                                    [50.9787, 50.9787]
# 3                                    [50.9787, 50.9787]
# 4                                    [50.9787, 50.9787]
# ...                                                 ...
# 4638  [49.98419, 49.98419, 49.98419, 49.98419, 49.98...
# 4639  [49.98419, 49.98419, 49.98419, 49.98419, 49.98...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                          [50.9787]
#
#                                              longitudes  \
# 0                                            [11.03283]
# 1                                            [11.03283]
# 2                                  [11.03283, 11.03283]
# 3                                  [11.03283, 11.03283]
# 4                                  [11.03283, 11.03283]
# ...                                                 ...
# 4638  [8.2791, 8.2791, 8.2791, 8.2791, 8.2791, 8.279...
# 4639  [8.2791, 8.2791, 8.2791, 8.2791, 8.2791, 8.279...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                         [11.03283]
#
#                                                     lat  \
# 0                                   [50.98476789999999]
# 1                                   [50.98476789999999]
# 2                [50.98476789999999, 50.98476789999999]
# 3                [50.98476789999999, 50.98476789999999]
# 4                [50.98476789999999, 50.98476789999999]
# ...                                                 ...
# 4638  [49.9928617, 49.9928617, 49.9928617, 49.992861...
# 4639  [49.9928617, 49.9928617, 49.9928617, 49.992861...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                [50.98476789999999]
#
#                                                     lng  \
# 0                                          [11.0298799]
# 1                                          [11.0298799]
# 2                              [11.0298799, 11.0298799]
# 3                              [11.0298799, 11.0298799]
# 4                              [11.0298799, 11.0298799]
# ...                                                 ...
# 4638  [8.2472526, 8.2472526, 8.2472526, 8.2472526, 8...
# 4639  [8.2472526, 8.2472526, 8.2472526, 8.2472526, 8...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                       [11.0298799]
#
#                                          Google address
# 0                                     [Erfurt, Germany]
# 1                                     [Erfurt, Germany]
# 2                    [Erfurt, Germany, Erfurt, Germany]
# 3                    [Erfurt, Germany, Erfurt, Germany]
# 4                    [Erfurt, Germany, Erfurt, Germany]
# ...                                                 ...
# 4638  [Mainz, Germany, Mainz, Germany, Mainz, German...
# 4639  [Mainz, Germany, Mainz, Germany, Mainz, German...
# 4640                               [nan, nan, nan, nan]
# 4641  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4642                                  [Erfurt, Germany]
#
# [4643 rows x 31 columns]

# %% [markdown]
# In **step 3**, we can flatten the information and only preserve unique information per cell.

# %%
# flatten data in dataframe cells

def flatten_list(cell):
    if isinstance(cell, list):
        unique_values = set(cell)
        return ', '.join(str(value) for value in unique_values)
    else:
        return str(cell)

# flatten all cells containing lists
df3 = grouped_df.applymap(flatten_list)

# show the flattened DataFrame
display(df3)
# Out:
#      pers_ID_FS         event_type            pers_function      pers_title  \
# 0             1  Funktionsausübung        Kriegszahlmeister             n/a
# 1            10           Aufnahme                   Bürger             n/a
# 2            10  Funktionsausübung                Fabrikant             n/a
# 3            10  Funktionsausübung  Kammer- und Zahlmeister             n/a
# 4            10  Funktionsausübung                Kammerrat             n/a
# ...         ...                ...                      ...             ...
# 4638      P-002                n/a                 Syndikus  Lic. iur. utr.
# 4639      P-002                n/a                 Syndikus             n/a
# 4640      P-002                n/a                      n/a   Dr. iur. utr.
# 4641      P-002                n/a                      n/a  Lic. iur. utr.
# 4642          X             Geburt                     Kind             n/a
#
#                    inst_name event_start event_after-date event_before-date  \
# 0           Kammer zu Erfurt  1781-00-00              n/a               n/a
# 1     Bürgerschaft zu Erfurt  1747-02-20              n/a               n/a
# 2                 Wollfabrik        0000             1750              1759
# 3           Kammer zu Erfurt  1766-00-00              n/a               n/a
# 4           Kammer zu Erfurt  1766-00-00              n/a               n/a
# ...                      ...         ...              ...               ...
# 4638       Universität Mainz  1746-00-00              n/a               n/a
# 4639       Universität Mainz  1742-00-00              n/a               n/a
# 4640                     n/a  1755-00-00              n/a               n/a
# 4641                     n/a  1740-00-00              n/a               n/a
# 4642                     n/a  16XX-00-00              n/a               n/a
#
#        event_end                                         factoid_ID  ...  \
# 0     1781-00-00                                     Erffurt_000158  ...
# 1     1747-02-20                                     Erffurt_000416  ...
# 2           0000                                     Erffurt_004934  ...
# 3     1766-00-00                                     Erffurt_000152  ...
# 4     1766-00-00                                     Erffurt_000151  ...
# ...          ...                                                ...  ...
# 4638  1753-00-00  Stk_31738, Stk_31740, Stk_31736, Stk_31748, St...  ...
# 4639  1756-00-00  Stk_31739, Stk_31751, Stk_31741, Stk_31737, St...  ...
# 4640  1756-00-00                               Stk_31766, Stk_31767  ...
# 4641  1753-00-00  Stk_31762, Stk_31764, Stk_31760, Stk_31763, St...  ...
# 4642  16XX-00-00                                     Erffurt_000836  ...
#
#      event_value place_name  addresses_full  \
# 0            n/a     Erfurt  Erfurt, Europe
# 1            n/a     Erfurt  Erfurt, Europe
# 2            n/a     Erfurt  Erfurt, Europe
# 3            n/a     Erfurt  Erfurt, Europe
# 4            n/a     Erfurt  Erfurt, Europe
# ...          ...        ...             ...
# 4638         n/a      Mainz   Mainz, Europe
# 4639         n/a      Mainz   Mainz, Europe
# 4640         n/a        n/a             nan
# 4641         n/a        n/a             nan
# 4642         n/a     Erfurt  Erfurt, Europe
#
#                                                     ids geonames address  \
# 0                                             2929670.0           Erfurt
# 1                                             2929670.0           Erfurt
# 2                                             2929670.0           Erfurt
# 3                                             2929670.0           Erfurt
# 4                                             2929670.0           Erfurt
# ...                                                 ...              ...
# 4638                                          2874225.0            Mainz
# 4639                                          2874225.0            Mainz
# 4640                                 nan, nan, nan, nan              nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...              nan
# 4642                                          2929670.0           Erfurt
#
#                                               latitudes  \
# 0                                               50.9787
# 1                                               50.9787
# 2                                               50.9787
# 3                                               50.9787
# 4                                               50.9787
# ...                                                 ...
# 4638                                           49.98419
# 4639                                           49.98419
# 4640                                 nan, nan, nan, nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# 4642                                            50.9787
#
#                                              longitudes  \
# 0                                              11.03283
# 1                                              11.03283
# 2                                              11.03283
# 3                                              11.03283
# 4                                              11.03283
# ...                                                 ...
# 4638                                             8.2791
# 4639                                             8.2791
# 4640                                 nan, nan, nan, nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# 4642                                           11.03283
#
#                                                     lat  \
# 0                                     50.98476789999999
# 1                                     50.98476789999999
# 2                                     50.98476789999999
# 3                                     50.98476789999999
# 4                                     50.98476789999999
# ...                                                 ...
# 4638                                         49.9928617
# 4639                                         49.9928617
# 4640                                 nan, nan, nan, nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# 4642                                  50.98476789999999
#
#                                                     lng   Google address
# 0                                            11.0298799  Erfurt, Germany
# 1                                            11.0298799  Erfurt, Germany
# 2                                            11.0298799  Erfurt, Germany
# 3                                            11.0298799  Erfurt, Germany
# 4                                            11.0298799  Erfurt, Germany
# ...                                                 ...              ...
# 4638                                          8.2472526   Mainz, Germany
# 4639                                          8.2472526   Mainz, Germany
# 4640                                 nan, nan, nan, nan              nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...              nan
# 4642                                         11.0298799  Erfurt, Germany
#
# [4643 rows x 31 columns]

# %% [markdown]
# In **step 4**, we enrich the data, e.g. by adding event values from an external Python dictionary stored in Github.

# %%
## load external dictionary with EVENT VALUES
# following method 2 on https://www.geeksforgeeks.org/how-to-read-dictionary-from-file-in-python/

# importing the module
import requests
import ast

master = "https://raw.githubusercontent.com/ieg-dhr/DigiKAR/main/Data%20Categorisation/Event_value_dict.txt" # add Sven's new mapping
req = requests.get(master)
req = req.text
print(req)

# reconstructing the data as a dictionary
event_value_dict = ast.literal_eval(req)
print(type(event_value_dict))

# add event values from dict to data frame

try:
    test = event_value_dict["Aufschwörung"] # random test if valid dict
    print("Value for chosen key: ", test)
except:
    print("Invalid dict structure!")

df3['event_value'] = df3['event_type'].map(event_value_dict) # optional: na_action='ignore'

display(df3)
# Out:
# {
#     "Amtsantritt": "K",
#     "Aufenthalt": "M",
#     "Beisetzung": "Z",
#     "Bewerbung": "I",
#     "Eheschließung": "P",
#     "Entlassung": "R",
#     "Erfolglose Bewerbung": "I",
#     "Flucht": "M",
#     "Funktionsausübung": "Q",
#     "Geburt": "A",
#     "Graduation": "G",
#     "Haft": "M",
#     "Immatrikulation": "C",
#     "Konflikt": "M",
#     "Konversion": "M",
#     "Mitgliedschaft": "L",
#     "Nicht-Ausübung": "N",
#     "Nobilitierung": "S",
#     "Ordination": "J",
#     "Primäre Bildungsstation": "B",
#     "Promotion": "H",
#     "Prüfung": "F",
#     "Resignation": "T",
#     "Rezeption": "K",
#     "Sonstiges": "M",
#     "Studium": "D",
#     "Taufe": "A",
#     "Tod": "Y",
#     "Verleihung eines Ehrentitels": "S",
#     "Wahl": "K",
#     "Weihe": "J",
#     "Wohnsitznahme": "O",
#     "Zulassung": "E"
#    }
#
#
# <class 'dict'>
# Invalid dict structure!
#      pers_ID_FS         event_type            pers_function      pers_title  \
# 0             1  Funktionsausübung        Kriegszahlmeister             n/a
# 1            10           Aufnahme                   Bürger             n/a
# 2            10  Funktionsausübung                Fabrikant             n/a
# 3            10  Funktionsausübung  Kammer- und Zahlmeister             n/a
# 4            10  Funktionsausübung                Kammerrat             n/a
# ...         ...                ...                      ...             ...
# 4638      P-002                n/a                 Syndikus  Lic. iur. utr.
# 4639      P-002                n/a                 Syndikus             n/a
# 4640      P-002                n/a                      n/a   Dr. iur. utr.
# 4641      P-002                n/a                      n/a  Lic. iur. utr.
# 4642          X             Geburt                     Kind             n/a
#
#                    inst_name event_start event_after-date event_before-date  \
# 0           Kammer zu Erfurt  1781-00-00              n/a               n/a
# 1     Bürgerschaft zu Erfurt  1747-02-20              n/a               n/a
# 2                 Wollfabrik        0000             1750              1759
# 3           Kammer zu Erfurt  1766-00-00              n/a               n/a
# 4           Kammer zu Erfurt  1766-00-00              n/a               n/a
# ...                      ...         ...              ...               ...
# 4638       Universität Mainz  1746-00-00              n/a               n/a
# 4639       Universität Mainz  1742-00-00              n/a               n/a
# 4640                     n/a  1755-00-00              n/a               n/a
# 4641                     n/a  1740-00-00              n/a               n/a
# 4642                     n/a  16XX-00-00              n/a               n/a
#
#        event_end                                         factoid_ID  ...  \
# 0     1781-00-00                                     Erffurt_000158  ...
# 1     1747-02-20                                     Erffurt_000416  ...
# 2           0000                                     Erffurt_004934  ...
# 3     1766-00-00                                     Erffurt_000152  ...
# 4     1766-00-00                                     Erffurt_000151  ...
# ...          ...                                                ...  ...
# 4638  1753-00-00  Stk_31738, Stk_31740, Stk_31736, Stk_31748, St...  ...
# 4639  1756-00-00  Stk_31739, Stk_31751, Stk_31741, Stk_31737, St...  ...
# 4640  1756-00-00                               Stk_31766, Stk_31767  ...
# 4641  1753-00-00  Stk_31762, Stk_31764, Stk_31760, Stk_31763, St...  ...
# 4642  16XX-00-00                                     Erffurt_000836  ...
#
#      event_value place_name  addresses_full  \
# 0              Q     Erfurt  Erfurt, Europe
# 1            NaN     Erfurt  Erfurt, Europe
# 2              Q     Erfurt  Erfurt, Europe
# 3              Q     Erfurt  Erfurt, Europe
# 4              Q     Erfurt  Erfurt, Europe
# ...          ...        ...             ...
# 4638         NaN      Mainz   Mainz, Europe
# 4639         NaN      Mainz   Mainz, Europe
# 4640         NaN        n/a             nan
# 4641         NaN        n/a             nan
# 4642           A     Erfurt  Erfurt, Europe
#
#                                                     ids geonames address  \
# 0                                             2929670.0           Erfurt
# 1                                             2929670.0           Erfurt
# 2                                             2929670.0           Erfurt
# 3                                             2929670.0           Erfurt
# 4                                             2929670.0           Erfurt
# ...                                                 ...              ...
# 4638                                          2874225.0            Mainz
# 4639                                          2874225.0            Mainz
# 4640                                 nan, nan, nan, nan              nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...              nan
# 4642                                          2929670.0           Erfurt
#
#                                               latitudes  \
# 0                                               50.9787
# 1                                               50.9787
# 2                                               50.9787
# 3                                               50.9787
# 4                                               50.9787
# ...                                                 ...
# 4638                                           49.98419
# 4639                                           49.98419
# 4640                                 nan, nan, nan, nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# 4642                                            50.9787
#
#                                              longitudes  \
# 0                                              11.03283
# 1                                              11.03283
# 2                                              11.03283
# 3                                              11.03283
# 4                                              11.03283
# ...                                                 ...
# 4638                                             8.2791
# 4639                                             8.2791
# 4640                                 nan, nan, nan, nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# 4642                                           11.03283
#
#                                                     lat  \
# 0                                     50.98476789999999
# 1                                     50.98476789999999
# 2                                     50.98476789999999
# 3                                     50.98476789999999
# 4                                     50.98476789999999
# ...                                                 ...
# 4638                                         49.9928617
# 4639                                         49.9928617
# 4640                                 nan, nan, nan, nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# 4642                                  50.98476789999999
#
#                                                     lng   Google address
# 0                                            11.0298799  Erfurt, Germany
# 1                                            11.0298799  Erfurt, Germany
# 2                                            11.0298799  Erfurt, Germany
# 3                                            11.0298799  Erfurt, Germany
# 4                                            11.0298799  Erfurt, Germany
# ...                                                 ...              ...
# 4638                                          8.2472526   Mainz, Germany
# 4639                                          8.2472526   Mainz, Germany
# 4640                                 nan, nan, nan, nan              nan
# 4641  nan, nan, nan, nan, nan, nan, nan, nan, nan, n...              nan
# 4642                                         11.0298799  Erfurt, Germany
#
# [4643 rows x 31 columns]

# %%
## load external dictionary with EVENT CATEGORIES (e.g. I: agent-oriented)
# following method 2 on https://www.geeksforgeeks.org/how-to-read-dictionary-from-file-in-python/

# importing the module
import requests
import ast

master = "https://raw.githubusercontent.com/ieg-dhr/DigiKAR/main/Data%20Categorisation/####.txt" # add file name
req = requests.get(master)
req = req.text
print(req)

# reconstructing the data as a dictionary
event_category_dict = ast.literal_eval(req)
print(type(event_category_dict))

# add event values from dict to data frame

try:
    test = event_category_dict["Geburt"] # random test if valid dict
    print("Value for chosen key: ", test)
except:
    print("Invalid dict structure!")

df3['event_category'] = df3['event_type'].map(event_category_dict) # optional: na_action='ignore'

display(df3)

# %%
## load external dictionary with FUNCTION CATEGORIES (e.g. teaching versus administration)
# following method 2 on https://www.geeksforgeeks.org/how-to-read-dictionary-from-file-in-python/

# importing the module
import requests
import ast

master = "https://raw.githubusercontent.com/ieg-dhr/DigiKAR/main/Data%20Categorisation/####.txt" # add file name
req = requests.get(master)
req = req.text
print(req)

# reconstructing the data as a dictionary
function_category_dict = ast.literal_eval(req)
print(type(function_category_dict))

# add event values from dict to data frame

try:
    test = function_category_dict["Professor"] # random test if valid dict
    print("Value for chosen key: ", test)
except:
    print("Invalid dict structure!")

df3['function_category'] = df3['pers_function'].map(function_category_dict) # optional: na_action='ignore'

display(df3)

# %%
# save enriched df to DRIVE

workbook=directory+'FACTOIDS_consolidated/Factoid_Staatskalender-Erfurt_consolidation_coordinates_event-values_person-IDs.xlsx'
print(workbook)
writer = pd.ExcelWriter(workbook, engine='xlsxwriter') # create a Pandas Excel writer using XlsxWriter as the engine.
df3.to_excel(writer, sheet_name='FactCons1') # Convert the dataframe to an XlsxWriter Excel object.
writer.save() # Close the Pandas Excel writer and output the Excel file.
print("Done.")
# Out:
# /content/drive/My Drive/Colab_DigiKAR/FACTOIDS_consolidated/Factoid_Staatskalender-Erfurt_consolidation_coordinates_event-values_person-IDs.xlsx
# <ipython-input-9-d414ca272e8f>:7: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save() # Close the Pandas Excel writer and output the Excel file.
# Done.

# %% [markdown]
# Check the output files and repeat process if necessary.
#
# Script by Monika Barget, Maastricht/Mainz
#
# June 2023
